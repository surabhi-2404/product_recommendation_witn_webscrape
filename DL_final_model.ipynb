# %% [markdown]
# <a href="https://colab.research.google.com/github/surabhi-2404/product_recommendation_witn_webscrape/blob/main/DL_final_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !unzip /electronics.zip
# Out:
# Archive:  /electronics.zip
#    creating: electronics/
#    creating: electronics/.ipynb_checkpoints/
#   inflating: electronics/.ipynb_checkpoints/AirConditionerselectronics_dataset_flipkart-checkpoint.csv
#   inflating: electronics/.ipynb_checkpoints/electronics_code-checkpoint.ipynb
#   inflating: electronics/.ipynb_checkpoints/laptop_dataset_flipkart-checkpoint.csv
#   inflating: electronics/.ipynb_checkpoints/recommendation_model-checkpoint.ipynb
#   inflating: electronics/.ipynb_checkpoints/refrigerators_dataset_flipkart-checkpoint.csv
#   inflating: electronics/.ipynb_checkpoints/smartphones_dataset_flipkart-checkpoint.csv
#   inflating: electronics/.ipynb_checkpoints/televisions_dataset_flipkart-checkpoint.csv
#   inflating: electronics/AirConditionerselectronics_dataset_flipkart.csv
#   inflating: electronics/electronics_code.ipynb
#   inflating: electronics/label_encoder.pkl
#   inflating: electronics/laptop_dataset_flipkart.csv
#   inflating: electronics/products_data.pkl
#   inflating: electronics/recommendation_model.ipynb
#   inflating: electronics/refrigerators_dataset_flipkart.csv
#   inflating: electronics/scaler.pkl
#   inflating: electronics/sentiment_model.pkl
#   inflating: electronics/similarity_matrix.pkl
#   inflating: electronics/smartphones_dataset_flipkart.csv
#   inflating: electronics/televisions_dataset_flipkart.csv
#    creating: footwear/
#    creating: footwear/.ipynb_checkpoints/
#   inflating: footwear/.ipynb_checkpoints/footwear_code-checkpoint.ipynb
#   inflating: footwear/.ipynb_checkpoints/mensfootwear_100_products-checkpoint.csv
#   inflating: footwear/.ipynb_checkpoints/Untitled-checkpoint.ipynb
#   inflating: footwear/.ipynb_checkpoints/womensfootwear_100_products-checkpoint.csv
#   inflating: footwear/footwear_code.ipynb
#   inflating: footwear/label_encoder.pkl
#   inflating: footwear/mensfootwear_100_products.csv
#   inflating: footwear/products_data.pkl
#   inflating: footwear/scaler.pkl
#   inflating: footwear/sentiment_model.pkl
#   inflating: footwear/similarity_matrix.pkl
#   inflating: footwear/Untitled.ipynb
#   inflating: footwear/womensfootwear_100_products.csv
#    creating: Wearables/
#    creating: Wearables/.ipynb_checkpoints/
#   inflating: Wearables/.ipynb_checkpoints/Headphones_dataset_flipkart-checkpoint.csv
#   inflating: Wearables/.ipynb_checkpoints/Smartwatches_dataset_flipkart-checkpoint.csv
#   inflating: Wearables/.ipynb_checkpoints/wearables_code-checkpoint.ipynb
#   inflating: Wearables/Headphones_dataset_flipkart.csv
#   inflating: Wearables/Smartwatches_dataset_flipkart.csv
#   inflating: Wearables/wearables_code.ipynb
#   inflating: base model.ipynb
#   inflating: data_visualization.ipynb
#   inflating: label_encoder.pkl
#   inflating: merged_data.ipynb
#   inflating: products_data.pkl
#   inflating: recommendation_model.ipynb
#   inflating: Recommendation_Model_og.ipynb
#   inflating: scaler.pkl
#   inflating: sentiment add.ipynb
#   inflating: sentiment_model.pkl
#   inflating: similarity_matrix.pkl
#    creating: beauty and care/
#    creating: beauty and care/.ipynb_checkpoints/
#   inflating: beauty and care/.ipynb_checkpoints/bathandbody_100_products-checkpoint.csv
#   inflating: beauty and care/.ipynb_checkpoints/code-checkpoint.ipynb
#   inflating: beauty and care/.ipynb_checkpoints/fragrance_100_products-checkpoint.csv
#   inflating: beauty and care/.ipynb_checkpoints/haircare_100_products-checkpoint.csv
#   inflating: beauty and care/.ipynb_checkpoints/mengrooming_100_products-checkpoint.csv
#   inflating: beauty and care/.ipynb_checkpoints/merged_data-checkpoint.ipynb
#   inflating: beauty and care/.ipynb_checkpoints/womenmakeup_100_products-checkpoint.csv
#   inflating: beauty and care/.ipynb_checkpoints/womenskincare_100_products-checkpoint.csv
#   inflating: beauty and care/bathandbody_100_products.csv
#   inflating: beauty and care/code.ipynb
#   inflating: beauty and care/fragrance_100_products.csv
#   inflating: beauty and care/haircare_100_products.csv
#   inflating: beauty and care/mengrooming_100_products.csv
#   inflating: beauty and care/merged_data.ipynb
#   inflating: beauty and care/womenmakeup_100_products.csv
#   inflating: beauty and care/womenskincare_100_products.csv

# %% [markdown]
# # Beauty and Care

# %% [markdown]
#  ML+DL (beauty and care)

# %%
# (beauty and care)

import pandas as pd
import numpy as np
import os
import glob
import joblib

from sklearn.preprocessing import MinMaxScaler, LabelEncoder
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.model_selection import LeaveOneOut, StratifiedKFold
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report
from sklearn.utils import resample
from sklearn.ensemble import RandomForestClassifier

from collections import Counter
from sentence_transformers import SentenceTransformer

import tensorflow as tf
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.models import Model


# ===============================
# LOAD DATA
# ===============================
def load_datasets_from_folder(folder_path):
    all_files = glob.glob(os.path.join(folder_path, "*.csv"))
    if len(all_files) == 0:
        raise Exception("No CSV files found in the folder!")

    df_list = [pd.read_csv(f) for f in all_files]
    df = pd.concat(df_list, ignore_index=True)
    print(f"Loaded {len(all_files)} files with {len(df)} records.")
    return df


# ===============================
# FILL AND ENCODE SENTIMENT
# ===============================
def fill_and_encode_sentiment(df):
    print("\n--- PROCESSING SENTIMENT ---")

    def rating_to_sentiment(r):
        if pd.isna(r):
            return 'na'
        elif r >= 4.0:
            return 'positive'
        elif r >= 3.0:
            return 'neutral'
        else:
            return 'negative'

    df['sentiment'] = df['sentiment'].fillna(
        df['overall_rating'].apply(rating_to_sentiment)
    )

    df['sentiment'] = df['sentiment'].astype(str).str.strip().str.lower()

    sentiment_map = {'negative': 0, 'neutral': 1, 'positive': 2}
    df['sentiment_score'] = df['sentiment'].map(sentiment_map)

    return df


def compute_weighted_rating(df, m=None):
    C = df['overall_rating'].mean()
    if m is None:
        m = df['overall_rating'].quantile(0.25)

    df['weighted_rating'] = (
        (df['overall_rating'] * 1.0 + C * m) / (1 + m)
    )
    return df


# ===============================
# TRAIN SENTIMENT MODEL
# ===============================
def train_sentiment_model(df):
    print("\n--- TRAINING SENTIMENT MODEL (AUTO-BALANCED & SAFE CV) ---")

    # Select required columns
    df_model = df[['overall_rating', 'sentiment']].copy()
    df_model['overall_rating'] = pd.to_numeric(
        df_model['overall_rating'], errors='coerce'
    )
    df_model = df_model.dropna()

    # Compute weighted rating
    df_model = compute_weighted_rating(df_model)

    # Check class distribution
    class_counts = Counter(df_model['sentiment'])
    print("Class distribution before balancing:", class_counts)

    # Balance data
    max_size = max(class_counts.values())
    balanced_dfs = []

    for label in class_counts:
        subset = df_model[df_model['sentiment'] == label]

        if len(subset) < max_size:
            subset = resample(
                subset,
                replace=True,
                n_samples=max_size,
                random_state=42
            )

        balanced_dfs.append(subset)

    df_balanced = pd.concat(balanced_dfs)

    # Features
    df_balanced['rating_diff'] = (
        df_balanced['overall_rating'] - df_balanced['weighted_rating']
    )

    X = df_balanced[['overall_rating', 'weighted_rating', 'rating_diff']].values

    le = LabelEncoder()
    y = le.fit_transform(df_balanced['sentiment'])

    # Safe CV
    min_class_size = min(Counter(y).values())
    n_splits = min(5, min_class_size)

    scaler = MinMaxScaler()
    X = scaler.fit_transform(X)

    if n_splits < 2:
        print("⚠️ Too few samples for CV. Training without cross-validation.")

        model = LogisticRegression(
            max_iter=1000,
            solver='liblinear',
            class_weight='balanced'
        )
        model.fit(X, y)

        y_pred = model.predict(X)
        y_true = y

        print(classification_report(
            y_true,
            y_pred,
            target_names=le.classes_,
            zero_division=0
        ))

    else:
        skf = StratifiedKFold(
            n_splits=n_splits,
            shuffle=True,
            random_state=42
        )

        y_true, y_pred = [], []

        for train_idx, test_idx in skf.split(X, y):
            X_train, X_test = X[train_idx], X[test_idx]
            y_train, y_test = y[train_idx], y[test_idx]

            model = LogisticRegression(
                max_iter=1000,
                solver='liblinear',
                class_weight='balanced'
            )
            model.fit(X_train, y_train)

            y_pred.extend(model.predict(X_test))
            y_true.extend(y_test)

        print("\nAccuracy:", round(accuracy_score(y_true, y_pred), 4))
        print(classification_report(
            y_true,
            y_pred,
            target_names=le.classes_,
            zero_division=0
        ))

    # Final model
    final_model = RandomForestClassifier(
        n_estimators=200,
        max_depth=None,
        class_weight='balanced',
        random_state=42
    )
    final_model.fit(X, y)

    joblib.dump(final_model, "sentiment_model.pkl")
    joblib.dump(le, "label_encoder.pkl")
    joblib.dump(scaler, "sentiment_scaler.pkl")

    print("✅ Sentiment model trained safely with class balancing.")
    return final_model, le


# ===============================
# AUTOENCODER RECOMMENDER
# ===============================
def train_autoencoder_recommender(df):
    print("\n--- TRAINING AUTOENCODER RECOMMENDER ---")

    X = df[['overall_rating', 'sentiment_score', 'product_price']].values
    X = MinMaxScaler().fit_transform(X)

    input_dim = X.shape[1]

    input_layer = Input(shape=(input_dim,))
    encoded = Dense(16, activation='relu')(input_layer)
    encoded = Dense(8, activation='relu')(encoded)
    decoded = Dense(input_dim, activation='linear')(encoded)

    autoencoder = Model(input_layer, decoded)
    autoencoder.compile(
    optimizer='adam',
    loss=tf.keras.losses.MeanSquaredError()
      )


    autoencoder.fit(X, X, epochs=30, batch_size=32, verbose=1)
    autoencoder.save("ae_recommender.h5")

    print("✅ Autoencoder recommender trained")


# ===============================
# PREPARE RECOMMENDATION DATA
# ===============================
def prepare_recommendation_data(df):
    print("\n--- PREPARING RECOMMENDATION DATA ---")

    df['user_id'] = 0
    df['product_id'] = df.index

    df = df[
        ['product_name', 'product_price', 'sentiment',
         'sentiment_score', 'category', 'overall_rating']
    ].copy()

    df['product_price'] = (
        df['product_price'].astype(str)
        .str.replace(r'[₹,\s]', '', regex=True)
    )
    df['product_price'] = pd.to_numeric(df['product_price'], errors='coerce')
    df['overall_rating'] = pd.to_numeric(df['overall_rating'], errors='coerce')

    df = df.dropna(
        subset=['product_name', 'product_price',
                'sentiment_score', 'overall_rating', 'category']
    )

    features = df[['overall_rating', 'sentiment_score', 'product_price']]
    scaler = MinMaxScaler()
    features_scaled = scaler.fit_transform(features)

    similarity_matrix = cosine_similarity(features_scaled)

    joblib.dump(df, "products_data.pkl")
    joblib.dump(similarity_matrix, "similarity_matrix.pkl")
    joblib.dump(scaler, "scaler.pkl")

    model_embed = SentenceTransformer('all-MiniLM-L6-v2')
    df['text_for_embedding'] = (
        df['product_name'].astype(str) + " " + df['category'].astype(str)
    )

    embeddings = model_embed.encode(
        df['text_for_embedding'].tolist(),
        convert_to_tensor=True
    )

    joblib.dump(embeddings.cpu().numpy(), "product_embeddings.pkl")
    joblib.dump(model_embed, "embedding_model.pkl")

    print("Recommendation data and embeddings saved.")
    return df


# ===============================
# RECOMMEND PRODUCTS
# ===============================
def recommend_products(user_input, top_n=5):
    ae_model = tf.keras.models.load_model("ae_recommender.h5")

    df = joblib.load("products_data.pkl")
    similarity_matrix = joblib.load("similarity_matrix.pkl")
    embeddings = joblib.load("product_embeddings.pkl")
    model_embed = joblib.load("embedding_model.pkl")

    X = df[['overall_rating', 'sentiment_score', 'product_price']].values
    X = MinMaxScaler().fit_transform(X)

    recon = ae_model.predict(X)
    recon_error = np.mean(np.square(X - recon), axis=1)

    df['ae_score'] = -recon_error
    df = df.sort_values('ae_score', ascending=False)

    input_embedding = model_embed.encode(
        user_input, convert_to_tensor=True
    )
    semantic_scores = cosine_similarity(
        input_embedding.reshape(1, -1), embeddings
    )[0]

    combined_scores = [(i, semantic_scores[i]) for i in range(len(df))]
    combined_scores.sort(key=lambda x: x[1], reverse=True)

    print(f"\n✅ Recommended products similar to '{user_input}':\n")

    for idx, score in combined_scores[:top_n]:
        p = df.iloc[idx]
        print(f"Product: {p['product_name']}")
        print(f"Category: {p['category']}")
        print(
            f"Rating: {p['overall_rating']} | "
            f"Sentiment: {p['sentiment']} | "
            f"Price: ₹{p['product_price']}"
        )
        print(f"Semantic Similarity Score: {round(score, 4)}")
        print("-" * 60)


# ===============================
# MAIN
# ===============================
if __name__ == "__main__":
    DATA_FOLDER = r"/content/beauty and care"

    df = load_datasets_from_folder(DATA_FOLDER)
    df = fill_and_encode_sentiment(df)

    df['product_price'] = (
    df['product_price']
    .astype(str)
    .str.replace(r'[₹,\s]', '', regex=True)
    )
    df['product_price'] = pd.to_numeric(df['product_price'], errors='coerce')

    train_sentiment_model(df)
    train_autoencoder_recommender(df)
    prepare_recommendation_data(df)

    while True:
        name = input("\nEnter product name for recommendation (or type exit): ")
        if name.lower() == "exit":
            break
        recommend_products(name)
# Out:
# Loaded 6 files with 600 records.
#
# --- PROCESSING SENTIMENT ---
#
# --- TRAINING SENTIMENT MODEL (AUTO-BALANCED & SAFE CV) ---
# Class distribution before balancing: Counter({'positive': 438, 'neutral': 76, 'negative': 1})
#
# Accuracy: 0.9954
#               precision    recall  f1-score   support
#
#     negative       0.99      1.00      0.99       438
#      neutral       1.00      0.99      0.99       438
#     positive       1.00      1.00      1.00       438
#
#     accuracy                           1.00      1314
#    macro avg       1.00      1.00      1.00      1314
# weighted avg       1.00      1.00      1.00      1314
#
# ✅ Sentiment model trained safely with class balancing.
#
# --- TRAINING AUTOENCODER RECOMMENDER ---
# Epoch 1/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: nan
# Epoch 2/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: nan
# Epoch 3/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: nan
# Epoch 4/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: nan
# Epoch 5/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: nan
# Epoch 6/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: nan
# Epoch 7/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: nan
# Epoch 8/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: nan
# Epoch 9/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: nan
# Epoch 10/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: nan
# Epoch 11/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: nan
# Epoch 12/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: nan
# Epoch 13/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: nan
# Epoch 14/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: nan
# Epoch 15/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: nan
# Epoch 16/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: nan
# Epoch 17/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: nan
# Epoch 18/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: nan
# Epoch 19/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: nan
# Epoch 20/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: nan
# Epoch 21/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: nan
# Epoch 22/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: nan
# Epoch 23/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: nan
# Epoch 24/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: nan
# Epoch 25/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: nan
# Epoch 26/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: nan
# Epoch 27/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: nan
# Epoch 28/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: nan
# Epoch 29/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: nan
# Epoch 30/30
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: nan
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ✅ Autoencoder recommender trained
#
# --- PREPARING RECOMMENDATION DATA ---
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Recommendation data and embeddings saved.
#
# Enter product name for recommendation (or type exit): lipstick
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
#
# ✅ Recommended products similar to 'lipstick':
#
# Product: Lakmé 9 To 7 Matte Bullet Lipstick
# Category: Beauty and Care
# Rating: 4.1 | Sentiment: positive | Price: ₹832.0
# Semantic Similarity Score: 0.6832000017166138
# ------------------------------------------------------------
# Product: MAYBELLINE NEW YORK Color Sensational Creamy Matte Lips...
# Category: Beauty and Care
# Rating: 4.2 | Sentiment: positive | Price: ₹177.0
# Semantic Similarity Score: 0.6762999892234802
# ------------------------------------------------------------
# Product: MAYBELLINE NEW YORK Baby Lips Loves NYC Tinted Lip Balm...
# Category: Beauty and Care
# Rating: 4.4 | Sentiment: positive | Price: ₹167.0
# Semantic Similarity Score: 0.61080002784729
# ------------------------------------------------------------
# Product: SUGAR Cosmetics Tipsy Lip Balm - Long Lasting Moisturiz...
# Category: Beauty and Care
# Rating: 4.4 | Sentiment: positive | Price: ₹149.0
# Semantic Similarity Score: 0.6080999970436096
# ------------------------------------------------------------
# Product: SUGAR Cosmetics Tipsy Lip Balm - Long Lasting Moisturiz...
# Category: Beauty and Care
# Rating: 4.3 | Sentiment: positive | Price: ₹159.0
# Semantic Similarity Score: 0.6080999970436096
# ------------------------------------------------------------
#
# Enter product name for recommendation (or type exit): perfume
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
#
# ✅ Recommended products similar to 'perfume':
#
# Product: Engage Gift Set Moments Perfume, Long Lasting Fragrance...
# Category: Beauty and Care
# Rating: 4.1 | Sentiment: positive | Price: ₹246.0
# Semantic Similarity Score: 0.7186999917030334
# ------------------------------------------------------------
# Product: FOGG Fresh Citrus Premium Perfume Scent With Long Lasti...
# Category: Beauty and Care
# Rating: 4.1 | Sentiment: positive | Price: ₹199.0
# Semantic Similarity Score: 0.6938999891281128
# ------------------------------------------------------------
# Product: FOGG Xtremo and Perfume Scent With Long Lasting Eau de ...
# Category: Beauty and Care
# Rating: 4.2 | Sentiment: positive | Price: ₹526.0
# Semantic Similarity Score: 0.6866999864578247
# ------------------------------------------------------------
# Product: FOGG Impressio Perfume Scent With Long Lasting II� Eau ...
# Category: Beauty and Care
# Rating: 4.2 | Sentiment: positive | Price: ₹157.0
# Semantic Similarity Score: 0.6865000128746033
# ------------------------------------------------------------
# Product: THE MAN COMPANY Black EDT Premium Long Lasting Perfume ...
# Category: Beauty and Care
# Rating: 4.0 | Sentiment: positive | Price: ₹474.0
# Semantic Similarity Score: 0.6863999962806702
# ------------------------------------------------------------
#
# Enter product name for recommendation (or type exit): exit

# %% [markdown]
# # DL (Autoencoder) only

# %%
# ===============================
# BEAUTY & CARE – DL ONLY VERSION
# ===============================

import pandas as pd
import numpy as np
import os
import glob
import joblib

from sklearn.preprocessing import MinMaxScaler, LabelEncoder
from sklearn.metrics import classification_report
from sklearn.metrics.pairwise import cosine_similarity

from sentence_transformers import SentenceTransformer

import tensorflow as tf
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.utils import to_categorical


# ===============================
# LOAD DATA
# ===============================
def load_datasets_from_folder(folder_path):
    all_files = glob.glob(os.path.join(folder_path, "*.csv"))
    if not all_files:
        raise Exception("No CSV files found!")

    df = pd.concat([pd.read_csv(f) for f in all_files], ignore_index=True)
    print(f"Loaded {len(df)} records")
    return df


# ===============================
# SENTIMENT PREPROCESSING
# ===============================
def fill_and_encode_sentiment(df):

    def rating_to_sentiment(r):
        if pd.isna(r):
            return 'neutral'
        elif r >= 4:
            return 'positive'
        elif r >= 3:
            return 'neutral'
        else:
            return 'negative'

    df['sentiment'] = df['sentiment'].fillna(
        df['overall_rating'].apply(rating_to_sentiment)
    )

    df['sentiment'] = df['sentiment'].str.lower().str.strip()

    sentiment_map = {'negative': 0, 'neutral': 1, 'positive': 2}
    df['sentiment_score'] = df['sentiment'].map(sentiment_map)

    return df


# ===============================
# DL SENTIMENT CLASSIFIER
# ===============================
def train_dl_sentiment_model(df):
    print("\n--- TRAINING DL SENTIMENT CLASSIFIER (BALANCED) ---")

    df = df.dropna(subset=['overall_rating', 'sentiment_score'])

    X = df[['overall_rating']].values
    y = df['sentiment_score'].values

    scaler = MinMaxScaler()
    X = scaler.fit_transform(X)

    y_cat = tf.keras.utils.to_categorical(y, num_classes=3)

    # 🔹 COMPUTE CLASS WEIGHTS
    class_counts = np.bincount(y)
    total = len(y)

    class_weights = {
        i: total / (3 * count) for i, count in enumerate(class_counts)
    }

    print("Class weights:", class_weights)

    # 🔹 DL MODEL
    model = tf.keras.Sequential([
        Dense(32, activation='relu', input_shape=(1,)),
        Dense(16, activation='relu'),
        Dense(3, activation='softmax')
    ])

    model.compile(
        optimizer='adam',
        loss='categorical_crossentropy',
        metrics=['accuracy']
    )

    model.fit(
        X,
        y_cat,
        epochs=30,
        batch_size=32,
        class_weight=class_weights,
        verbose=1
    )

    # 🔹 EVALUATION
    y_pred = model.predict(X)
    y_pred_labels = np.argmax(y_pred, axis=1)

    print("\n📊 DL Classification Report (Balanced):\n")
    print(classification_report(
        y,
        y_pred_labels,
        target_names=['negative', 'neutral', 'positive'],
        zero_division=0
    ))

    model.save("dl_sentiment_model.h5")
    joblib.dump(scaler, "dl_sentiment_scaler.pkl")

    print("✅ DL sentiment model trained with class balancing")


# ===============================
# AUTOENCODER RECOMMENDER (DL)
# ===============================
def train_autoencoder_recommender(df):
    print("\n--- TRAINING AUTOENCODER RECOMMENDER ---")

    df = df.dropna(subset=['overall_rating', 'sentiment_score', 'product_price'])

    X = df[['overall_rating', 'sentiment_score', 'product_price']].values
    X = MinMaxScaler().fit_transform(X)

    input_layer = Input(shape=(3,))
    encoded = Dense(16, activation='relu')(input_layer)
    encoded = Dense(8, activation='relu')(encoded)
    decoded = Dense(3, activation='linear')(encoded)

    autoencoder = Model(input_layer, decoded)
    autoencoder.compile(
        optimizer='adam',
        loss=tf.keras.losses.MeanSquaredError()
    )

    autoencoder.fit(X, X, epochs=30, batch_size=32, verbose=1)
    autoencoder.save("ae_recommender.h5")

    print("✅ Autoencoder trained")


# ===============================
# PREPARE RECOMMENDATION DATA
# ===============================
def prepare_recommendation_data(df):
    print("\n--- PREPARING RECOMMENDATION DATA ---")

    df = df.dropna(subset=[
        'product_name', 'category',
        'product_price', 'overall_rating', 'sentiment_score'
    ])

    features = df[['overall_rating', 'sentiment_score', 'product_price']]
    scaler = MinMaxScaler()
    features_scaled = scaler.fit_transform(features)

    similarity_matrix = cosine_similarity(features_scaled)

    joblib.dump(df, "products_data.pkl")
    joblib.dump(similarity_matrix, "similarity_matrix.pkl")

    model_embed = SentenceTransformer('all-MiniLM-L6-v2')
    df['text'] = df['product_name'] + " " + df['category']
    embeddings = model_embed.encode(df['text'].tolist(), convert_to_tensor=True)

    joblib.dump(embeddings.cpu().numpy(), "product_embeddings.pkl")
    joblib.dump(model_embed, "embedding_model.pkl")

    print("✅ Recommendation data ready")


# ===============================
# RECOMMEND PRODUCTS
# ===============================
def recommend_products(user_input, top_n=5):

    df = joblib.load("products_data.pkl")
    embeddings = joblib.load("product_embeddings.pkl")
    model_embed = joblib.load("embedding_model.pkl")

    query_emb = model_embed.encode(user_input, convert_to_tensor=True)
    scores = cosine_similarity(query_emb.reshape(1, -1), embeddings)[0]

    top_idx = np.argsort(scores)[::-1][:top_n]

    print(f"\n✅ Recommendations for '{user_input}':\n")

    for i in top_idx:
        p = df.iloc[i]
        print(f"Product: {p['product_name']}")
        print(f"Category: {p['category']}")
        print(f"Rating: {p['overall_rating']} | Price: ₹{p['product_price']}")
        print("-" * 50)


# ===============================
# MAIN
# ===============================
if __name__ == "__main__":

    DATA_FOLDER = r"/content/beauty and care"

    df = load_datasets_from_folder(DATA_FOLDER)
    df = fill_and_encode_sentiment(df)

    # Clean price globally
    df['product_price'] = (
        df['product_price']
        .astype(str)
        .str.replace(r'[₹,\s]', '', regex=True)
    )
    df['product_price'] = pd.to_numeric(df['product_price'], errors='coerce')

    train_dl_sentiment_model(df)
    train_autoencoder_recommender(df)
    prepare_recommendation_data(df)

    while True:
        name = input("\nEnter product name (or exit): ")
        if name.lower() == "exit":
            break
        recommend_products(name)
# Out:
# Loaded 600 records
#
# --- TRAINING DL SENTIMENT CLASSIFIER (BALANCED) ---
# Class weights: {0: np.float64(171.66666666666666), 1: np.float64(2.258771929824561), 2: np.float64(0.3919330289193303)}
# Epoch 1/30
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.1287 - loss: 1.2689
# Epoch 2/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8372 - loss: 1.2067
# Epoch 3/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8395 - loss: 1.1819
# Epoch 4/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8420 - loss: 1.8351
# Epoch 5/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8470 - loss: 0.7478
# Epoch 6/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8545 - loss: 1.4492
# Epoch 7/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8662 - loss: 0.7172
# Epoch 8/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8430 - loss: 0.8732
# Epoch 9/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8503 - loss: 1.2315
# Epoch 10/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8542 - loss: 0.6195
# Epoch 11/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8580 - loss: 0.6407
# Epoch 12/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8588 - loss: 0.7752
# Epoch 13/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8625 - loss: 0.7214
# Epoch 14/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8402 - loss: 0.9913
# Epoch 15/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8587 - loss: 0.7814
# Epoch 16/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8546 - loss: 0.5932
# Epoch 17/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8544 - loss: 0.8697
# Epoch 18/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8546 - loss: 0.6058
# Epoch 19/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8635 - loss: 1.2330
# Epoch 20/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8549 - loss: 0.6466
# Epoch 21/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8593 - loss: 0.5552
# Epoch 22/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8660 - loss: 0.6143
# Epoch 23/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8537 - loss: 0.8249
# Epoch 24/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8724 - loss: 0.6925
# Epoch 25/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8415 - loss: 0.7029
# Epoch 26/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8655 - loss: 0.4847
# Epoch 27/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8337 - loss: 0.7435
# Epoch 28/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8310 - loss: 0.7821
# Epoch 29/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8444 - loss: 0.5959
# Epoch 30/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8643 - loss: 0.6970
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 📊 DL Classification Report (Balanced):
#
#               precision    recall  f1-score   support
#
#     negative       1.00      1.00      1.00         1
#      neutral       1.00      0.05      0.10        76
#     positive       0.86      1.00      0.92       438
#
#     accuracy                           0.86       515
#    macro avg       0.95      0.68      0.67       515
# weighted avg       0.88      0.86      0.80       515
#
# ✅ DL sentiment model trained with class balancing
#
# --- TRAINING AUTOENCODER RECOMMENDER ---
# Epoch 1/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.4882
# Epoch 2/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2901
# Epoch 3/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1903
# Epoch 4/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1353
# Epoch 5/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0985
# Epoch 6/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0754
# Epoch 7/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0626
# Epoch 8/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0496
# Epoch 9/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0389
# Epoch 10/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0296
# Epoch 11/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0229
# Epoch 12/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0176
# Epoch 13/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0136
# Epoch 14/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0130
# Epoch 15/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0089
# Epoch 16/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0071
# Epoch 17/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0054
# Epoch 18/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0052
# Epoch 19/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0047
# Epoch 20/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0037
# Epoch 21/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0035
# Epoch 22/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0029
# Epoch 23/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0026
# Epoch 24/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0030
# Epoch 25/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0026
# Epoch 26/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0021
# Epoch 27/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0018
# Epoch 28/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0021
# Epoch 29/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0023
# Epoch 30/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0018
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ✅ Autoencoder trained
#
# --- PREPARING RECOMMENDATION DATA ---
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# /tmp/ipython-input-44016809.py:178: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['text'] = df['product_name'] + " " + df['category']
# ✅ Recommendation data ready
#
# Enter product name (or exit): lipstick
#
# ✅ Recommendations for 'lipstick':
#
# Product: Lakmé 9 To 7 Matte Bullet Lipstick
# Category: Beauty and Care
# Rating: 4.1 | Price: ₹832.0
# --------------------------------------------------
# Product: MAYBELLINE NEW YORK Color Sensational Creamy Matte Lips...
# Category: Beauty and Care
# Rating: 4.2 | Price: ₹177.0
# --------------------------------------------------
# Product: MAYBELLINE NEW YORK Baby Lips Loves NYC Tinted Lip Balm...
# Category: Beauty and Care
# Rating: 4.4 | Price: ₹167.0
# --------------------------------------------------
# Product: SUGAR Cosmetics Tipsy Lip Balm - Long Lasting Moisturiz...
# Category: Beauty and Care
# Rating: 4.4 | Price: ₹149.0
# --------------------------------------------------
# Product: SUGAR Cosmetics Tipsy Lip Balm - Long Lasting Moisturiz...
# Category: Beauty and Care
# Rating: 4.3 | Price: ₹159.0
# --------------------------------------------------
#
# Enter product name (or exit): perfume
#
# ✅ Recommendations for 'perfume':
#
# Product: Engage Gift Set Moments Perfume, Long Lasting Fragrance...
# Category: Beauty and Care
# Rating: 4.1 | Price: ₹246.0
# --------------------------------------------------
# Product: FOGG Fresh Citrus Premium Perfume Scent With Long Lasti...
# Category: Beauty and Care
# Rating: 4.1 | Price: ₹199.0
# --------------------------------------------------
# Product: FOGG Xtremo and Perfume Scent With Long Lasting Eau de ...
# Category: Beauty and Care
# Rating: 4.2 | Price: ₹526.0
# --------------------------------------------------
# Product: FOGG Impressio Perfume Scent With Long Lasting II� Eau ...
# Category: Beauty and Care
# Rating: 4.2 | Price: ₹157.0
# --------------------------------------------------
# Product: THE MAN COMPANY Black EDT Premium Long Lasting Perfume ...
# Category: Beauty and Care
# Rating: 4.0 | Price: ₹474.0
# --------------------------------------------------
#
# Enter product name (or exit): makeup
#
# ✅ Recommendations for 'makeup':
#
# Product: NYN Makeup Kit - Eye-Shadows, Lip Colors, Blushes, Spon...
# Category: Beauty and Care
# Rating: 3.7 | Price: ₹165.0
# --------------------------------------------------
# Product: NYN Makeup Kit - Eye-Shadows, Lip Colors, Blushes, Spon...
# Category: Beauty and Care
# Rating: 3.9 | Price: ₹164.0
# --------------------------------------------------
# Product: NYN Professional Makeup Kit (80133B)
# Category: Beauty and Care
# Rating: 3.9 | Price: ₹165.0
# --------------------------------------------------
# Product: VOZO Makeup Combo Kit One-stop Beauty Package for Begin...
# Category: Beauty and Care
# Rating: 3.9 | Price: ₹290.0
# --------------------------------------------------
# Product: VOZO Makeup Combo Kit One-stop Beauty Package for Begin...
# Category: Beauty and Care
# Rating: 3.8 | Price: ₹259.0
# --------------------------------------------------
#
# Enter product name (or exit): exit

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # LSTM+Attention

# %%
# ===============================
# BEAUTY & CARE – DL ONLY VERSION
# ===============================

import pandas as pd
import numpy as np
import os
import glob
import joblib

from sklearn.preprocessing import MinMaxScaler, LabelEncoder
from sklearn.metrics import classification_report
from sklearn.metrics.pairwise import cosine_similarity

from sentence_transformers import SentenceTransformer

import tensorflow as tf
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import LSTM, Attention, Reshape, Flatten


# ===============================
# LOAD DATA
# ===============================
def load_datasets_from_folder(folder_path):
    all_files = glob.glob(os.path.join(folder_path, "*.csv"))
    if not all_files:
        raise Exception("No CSV files found!")

    df = pd.concat([pd.read_csv(f) for f in all_files], ignore_index=True)
    print(f"Loaded {len(df)} records")
    return df


# ===============================
# SENTIMENT PREPROCESSING
# ===============================
def fill_and_encode_sentiment(df):

    def rating_to_sentiment(r):
        if pd.isna(r):
            return 'neutral'
        elif r >= 4:
            return 'positive'
        elif r >= 3:
            return 'neutral'
        else:
            return 'negative'

    df['sentiment'] = df['sentiment'].fillna(
        df['overall_rating'].apply(rating_to_sentiment)
    )

    df['sentiment'] = df['sentiment'].str.lower().str.strip()

    sentiment_map = {'negative': 0, 'neutral': 1, 'positive': 2}
    df['sentiment_score'] = df['sentiment'].map(sentiment_map)

    return df


# ===============================
# DL SENTIMENT CLASSIFIER
# ===============================
def train_dl_sentiment_model(df):
    print("\n--- TRAINING DL SENTIMENT CLASSIFIER (BALANCED) ---")

    df = df.dropna(subset=['overall_rating', 'sentiment_score'])

    X = df[['overall_rating']].values
    y = df['sentiment_score'].values

    scaler = MinMaxScaler()
    X = scaler.fit_transform(X)

    y_cat = tf.keras.utils.to_categorical(y, num_classes=3)

    # 🔹 COMPUTE CLASS WEIGHTS
    class_counts = np.bincount(y)
    total = len(y)

    class_weights = {
        i: total / (3 * count) for i, count in enumerate(class_counts)
    }

    print("Class weights:", class_weights)

    # 🔹 DL MODEL
    model = tf.keras.Sequential([
        Dense(32, activation='relu', input_shape=(1,)),
        Dense(16, activation='relu'),
        Dense(3, activation='softmax')
    ])

    model.compile(
        optimizer='adam',
        loss='categorical_crossentropy',
        metrics=['accuracy']
    )

    model.fit(
        X,
        y_cat,
        epochs=30,
        batch_size=32,
        class_weight=class_weights,
        verbose=1
    )

    # 🔹 EVALUATION
    y_pred = model.predict(X)
    y_pred_labels = np.argmax(y_pred, axis=1)

    print("\n📊 DL Classification Report (Balanced):\n")
    print(classification_report(
        y,
        y_pred_labels,
        target_names=['negative', 'neutral', 'positive'],
        zero_division=0
    ))

    model.save("dl_sentiment_model.h5")
    joblib.dump(scaler, "dl_sentiment_scaler.pkl")

    print("✅ DL sentiment model trained with class balancing")


# ===============================
# LSTM + ATTENTION RECOMMENDER (DL)
# ===============================
def train_lstm_attention_recommender(df):
    print("\n--- TRAINING LSTM + ATTENTION RECOMMENDER ---")

    df = df.dropna(subset=['overall_rating', 'sentiment_score', 'product_price'])

    # 🔹 Feature matrix
    X = df[['overall_rating', 'sentiment_score', 'product_price']].values
    X = MinMaxScaler().fit_transform(X)

    # 🔹 Convert to sequence format (timesteps = features)
    # Shape: (samples, timesteps, features_per_step)
    X_seq = X.reshape((X.shape[0], X.shape[1], 1))

    # 🔹 INPUT
    input_layer = Input(shape=(X_seq.shape[1], 1))

    # 🔹 LSTM
    lstm_out = LSTM(64, return_sequences=True)(input_layer)

    # 🔹 ATTENTION
    attention_out = Attention()([lstm_out, lstm_out])

    # 🔹 FLATTEN
    flat = Flatten()(attention_out)

    # 🔹 OUTPUT (reconstruct input features)
    output_layer = Dense(X.shape[1], activation='linear')(flat)

    # 🔹 MODEL
    model = Model(inputs=input_layer, outputs=output_layer)

    model.compile(
        optimizer='adam',
        loss=tf.keras.losses.MeanSquaredError()
    )

    model.fit(
        X_seq,
        X,
        epochs=30,
        batch_size=32,
        verbose=1
    )

    model.save("lstm_attention_recommender.h5")

    print("✅ LSTM + Attention recommender trained")

# ===============================
# PREPARE RECOMMENDATION DATA
# ===============================
def prepare_recommendation_data(df):
    print("\n--- PREPARING RECOMMENDATION DATA ---")

    df = df.dropna(subset=[
        'product_name', 'category',
        'product_price', 'overall_rating', 'sentiment_score'
    ])

    features = df[['overall_rating', 'sentiment_score', 'product_price']]
    scaler = MinMaxScaler()
    features_scaled = scaler.fit_transform(features)

    similarity_matrix = cosine_similarity(features_scaled)

    joblib.dump(df, "products_data.pkl")
    joblib.dump(similarity_matrix, "similarity_matrix.pkl")

    model_embed = SentenceTransformer('all-MiniLM-L6-v2')
    df['text'] = df['product_name'] + " " + df['category']
    embeddings = model_embed.encode(df['text'].tolist(), convert_to_tensor=True)

    joblib.dump(embeddings.cpu().numpy(), "product_embeddings.pkl")
    joblib.dump(model_embed, "embedding_model.pkl")

    print("✅ Recommendation data ready")


# ===============================
# RECOMMEND PRODUCTS
# ===============================
def recommend_products(user_input, top_n=5):

    df = joblib.load("products_data.pkl")
    embeddings = joblib.load("product_embeddings.pkl")
    model_embed = joblib.load("embedding_model.pkl")

    query_emb = model_embed.encode(user_input, convert_to_tensor=True)
    scores = cosine_similarity(query_emb.reshape(1, -1), embeddings)[0]

    top_idx = np.argsort(scores)[::-1][:top_n]

    print(f"\n✅ Recommendations for '{user_input}':\n")

    for i in top_idx:
        p = df.iloc[i]
        print(f"Product: {p['product_name']}")
        print(f"Category: {p['category']}")
        print(f"Rating: {p['overall_rating']} | Price: ₹{p['product_price']}")
        print("-" * 50)


# ===============================
# MAIN
# ===============================
if __name__ == "__main__":

    DATA_FOLDER = r"/content/beauty and care"

    df = load_datasets_from_folder(DATA_FOLDER)
    df = fill_and_encode_sentiment(df)

    # Clean price globally
    df['product_price'] = (
        df['product_price']
        .astype(str)
        .str.replace(r'[₹,\s]', '', regex=True)
    )
    df['product_price'] = pd.to_numeric(df['product_price'], errors='coerce')

    train_dl_sentiment_model(df)
    train_lstm_attention_recommender(df)
    prepare_recommendation_data(df)

    while True:
        name = input("\nEnter product name (or exit): ")
        if name.lower() == "exit":
            break
        recommend_products(name)
# Out:
# Loaded 600 records
#
# --- TRAINING DL SENTIMENT CLASSIFIER (BALANCED) ---
# Class weights: {0: np.float64(171.66666666666666), 1: np.float64(2.258771929824561), 2: np.float64(0.3919330289193303)}
# Epoch 1/30
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.1083 - loss: 1.6070
# Epoch 2/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8444 - loss: 1.0644
# Epoch 3/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8622 - loss: 1.1168
# Epoch 4/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8656 - loss: 1.4461
# Epoch 5/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8457 - loss: 0.9226
# Epoch 6/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8740 - loss: 1.0440
# Epoch 7/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8603 - loss: 0.7332
# Epoch 8/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8508 - loss: 0.7668
# Epoch 9/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8725 - loss: 0.6051
# Epoch 10/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8274 - loss: 1.0315
# Epoch 11/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8417 - loss: 1.3945
# Epoch 12/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8564 - loss: 0.7598
# Epoch 13/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8386 - loss: 0.7551
# Epoch 14/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8484 - loss: 0.7881
# Epoch 15/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8700 - loss: 1.1131
# Epoch 16/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8543 - loss: 0.7172
# Epoch 17/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8852 - loss: 0.8129
# Epoch 18/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8552 - loss: 0.8140
# Epoch 19/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8155 - loss: 1.0702
# Epoch 20/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8650 - loss: 0.5380
# Epoch 21/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8471 - loss: 0.7255
# Epoch 22/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8555 - loss: 1.5155
# Epoch 23/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8672 - loss: 1.4752
# Epoch 24/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8514 - loss: 0.5838
# Epoch 25/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8494 - loss: 0.6069
# Epoch 26/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8549 - loss: 0.9443
# Epoch 27/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8731 - loss: 0.5250
# Epoch 28/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8649 - loss: 0.5475
# Epoch 29/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8271 - loss: 0.6811
# Epoch 30/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8406 - loss: 0.5234
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 📊 DL Classification Report (Balanced):
#
#               precision    recall  f1-score   support
#
#     negative       1.00      1.00      1.00         1
#      neutral       1.00      0.04      0.08        76
#     positive       0.86      1.00      0.92       438
#
#     accuracy                           0.86       515
#    macro avg       0.95      0.68      0.67       515
# weighted avg       0.88      0.86      0.80       515
#
# ✅ DL sentiment model trained with class balancing
#
# --- TRAINING LSTM + ATTENTION RECOMMENDER ---
# Epoch 1/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.4426
# Epoch 2/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2352
# Epoch 3/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0397
# Epoch 4/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0124
# Epoch 5/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0072
# Epoch 6/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0058
# Epoch 7/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0052
# Epoch 8/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0044
# Epoch 9/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0047
# Epoch 10/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0048
# Epoch 11/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0042
# Epoch 12/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0064
# Epoch 13/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0053
# Epoch 14/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0053
# Epoch 15/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0048
# Epoch 16/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0038
# Epoch 17/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0041
# Epoch 18/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0044
# Epoch 19/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0051
# Epoch 20/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0043
# Epoch 21/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0044
# Epoch 22/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0046
# Epoch 23/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0040
# Epoch 24/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0047
# Epoch 25/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0042
# Epoch 26/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0046
# Epoch 27/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0036
# Epoch 28/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0050
# Epoch 29/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0032
# Epoch 30/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0037
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ✅ LSTM + Attention recommender trained
#
# --- PREPARING RECOMMENDATION DATA ---
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# /tmp/ipython-input-37069537.py:202: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['text'] = df['product_name'] + " " + df['category']
# ✅ Recommendation data ready
#
# Enter product name (or exit): grooming
#
# ✅ Recommendations for 'grooming':
#
# Product: TRU HAIR & SKIN All-in-One Mens Grooming Set | Hair Wax...
# Category: Beauty and Care
# Rating: 4.0 | Price: ₹450.0
# --------------------------------------------------
# Product: Wild Stone Edge Grooming Kit for Men | 7 IN 1 Gifting C...
# Category: Beauty and Care
# Rating: 4.6 | Price: ₹549.0
# --------------------------------------------------
# Product: VETONI Men's Grooming Kit
# Category: Beauty and Care
# Rating: 4.3 | Price: ₹234.0
# --------------------------------------------------
# Product: DENVER Blackcode Men's Grooming Kit
# Category: Beauty and Care
# Rating: 4.1 | Price: ₹334.0
# --------------------------------------------------
# Product: Yardley London Gentleman Luxury Grooming Kit- Elite Gif...
# Category: Beauty and Care
# Rating: 4.3 | Price: ₹356.0
# --------------------------------------------------
#
# Enter product name (or exit): trimmer
#
# ✅ Recommendations for 'trimmer':
#
# Product: Flemmi Professional Series 10 peice Hair cut Styling ha...
# Category: Beauty and Care
# Rating: 4.1 | Price: ₹89.0
# --------------------------------------------------
# Product: D-DIVINE Inch Natural Brown Straight Extension 5 Clip ...
# Category: Beauty and Care
# Rating: 3.0 | Price: ₹186.0
# --------------------------------------------------
# Product: D-DIVINE 5 Clip 24 Inch Natural Brown Straight Hair Ext...
# Category: Beauty and Care
# Rating: 3.9 | Price: ₹186.0
# --------------------------------------------------
# Product: Gillette Presto Razor (14pcs), Shaving Cream (25g)
# Category: Beauty and Care
# Rating: 4.2 | Price: ₹288.0
# --------------------------------------------------
# Product: BOMBAY SHAVING COMPANY 9in1 Travel Shaving and Grooming...
# Category: Beauty and Care
# Rating: 4.2 | Price: ₹398.0
# --------------------------------------------------
#
# Enter product name (or exit): blush
#
# ✅ Recommendations for 'blush':
#
# Product: MARS 6 Shade illuminating and Blusher Palette Highlight...
# Category: Beauty and Care
# Rating: 4.4 | Price: ₹289.0
# --------------------------------------------------
# Product: NYN Makeup Kit - Eye-Shadows, Lip Colors, Blushes, Spon...
# Category: Beauty and Care
# Rating: 3.7 | Price: ₹165.0
# --------------------------------------------------
# Product: NYN Makeup Kit - Eye-Shadows, Lip Colors, Blushes, Spon...
# Category: Beauty and Care
# Rating: 3.9 | Price: ₹164.0
# --------------------------------------------------
# Product: vellasio Strobe Cream Gold & Blush Pink Combo Highlight...
# Category: Beauty and Care
# Rating: 4.5 | Price: ₹265.0
# --------------------------------------------------
# Product: vellasio Strobe Cream Gold & Blush Pink Combo Highlight...
# Category: Beauty and Care
# Rating: 4.5 | Price: ₹265.0
# --------------------------------------------------
#
# Enter product name (or exit): exit

# %% [markdown]
# # CNN + Attention DL

# %%
# ===============================
# BEAUTY & CARE – DL ONLY VERSION
# ===============================

import pandas as pd
import numpy as np
import os
import glob
import joblib

from sklearn.preprocessing import MinMaxScaler, LabelEncoder
from sklearn.metrics import classification_report
from sklearn.metrics.pairwise import cosine_similarity

from sentence_transformers import SentenceTransformer

import tensorflow as tf
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Conv1D, GlobalAveragePooling1D
from tensorflow.keras.layers import Attention, Reshape


# ===============================
# LOAD DATA
# ===============================
def load_datasets_from_folder(folder_path):
    all_files = glob.glob(os.path.join(folder_path, "*.csv"))
    if not all_files:
        raise Exception("No CSV files found!")

    df = pd.concat([pd.read_csv(f) for f in all_files], ignore_index=True)
    print(f"Loaded {len(df)} records")
    return df


# ===============================
# SENTIMENT PREPROCESSING
# ===============================
def fill_and_encode_sentiment(df):

    def rating_to_sentiment(r):
        if pd.isna(r):
            return 'neutral'
        elif r >= 4:
            return 'positive'
        elif r >= 3:
            return 'neutral'
        else:
            return 'negative'

    df['sentiment'] = df['sentiment'].fillna(
        df['overall_rating'].apply(rating_to_sentiment)
    )

    df['sentiment'] = df['sentiment'].str.lower().str.strip()

    sentiment_map = {'negative': 0, 'neutral': 1, 'positive': 2}
    df['sentiment_score'] = df['sentiment'].map(sentiment_map)

    return df


# ===============================
# DL SENTIMENT CLASSIFIER
# ===============================
def train_dl_sentiment_model(df):
    print("\n--- TRAINING DL SENTIMENT CLASSIFIER (BALANCED) ---")

    df = df.dropna(subset=['overall_rating', 'sentiment_score'])

    df['neutral_distance'] = np.abs(df['overall_rating'] - 3)

    X = df[['overall_rating', 'neutral_distance']].values

    y = df['sentiment_score'].values

    scaler = MinMaxScaler()
    X = scaler.fit_transform(X)

    y_cat = tf.keras.utils.to_categorical(y, num_classes=3)

    # 🔹 COMPUTE CLASS WEIGHTS
    class_counts = np.bincount(y)
    total = len(y)

    class_weights = {
        i: total / (3 * count) for i, count in enumerate(class_counts)
    }

    print("Class weights:", class_weights)

    # 🔹 DL MODEL
    model = tf.keras.Sequential([
        Dense(32, activation='relu', input_shape=(2,)),
        Dense(16, activation='relu'),
        Dense(3, activation='softmax')
    ])

    model.compile(
        optimizer='adam',
        loss=tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.1),
        metrics=['accuracy']
    )

    model.fit(
        X,
        y_cat,
        epochs=30,
        batch_size=32,
        class_weight=class_weights,
        verbose=1
    )

    # 🔹 EVALUATION
    y_pred = model.predict(X)
    y_pred_labels = np.argmax(y_pred, axis=1)

    print("\n📊 DL Classification Report (Balanced):\n")
    print(classification_report(
        y,
        y_pred_labels,
        target_names=['negative', 'neutral', 'positive'],
        zero_division=0
    ))

    model.save("dl_sentiment_model.h5")
    joblib.dump(scaler, "dl_sentiment_scaler.pkl")

    print("✅ DL sentiment model trained with class balancing")


# ===============================
# CNN + ATTENTION RECOMMENDER (DL)
# ===============================
def train_cnn_attention_recommender(df):
    print("\n--- TRAINING CNN + ATTENTION RECOMMENDER ---")

    df = df.dropna(subset=['overall_rating', 'sentiment_score', 'product_price'])

    # 🔹 Feature matrix
    df['neutral_distance'] = np.abs(df['overall_rating'] - 3)

    X = df[['overall_rating', 'neutral_distance']].values

    X = MinMaxScaler().fit_transform(X)

    # 🔹 Reshape for CNN
    # Shape: (samples, timesteps, channels)
    X_seq = X.reshape((X.shape[0], X.shape[1], 1))

    # 🔹 INPUT
    input_layer = Input(shape=(X_seq.shape[1], 1))

    # 🔹 CNN layers
    conv1 = Conv1D(filters=64, kernel_size=2, activation='relu', padding='same')(input_layer)
    conv2 = Conv1D(filters=32, kernel_size=2, activation='relu', padding='same')(conv1)

    # 🔹 ATTENTION
    attention_out = Attention()([conv2, conv2])

    # 🔹 POOLING
    pooled = GlobalAveragePooling1D()(attention_out)

    # 🔹 OUTPUT (reconstruction)
    output_layer = Dense(X.shape[1], activation='linear')(pooled)

    # 🔹 MODEL
    model = Model(inputs=input_layer, outputs=output_layer)

    model.compile(
        optimizer='adam',
        loss=tf.keras.losses.MeanSquaredError()
    )

    model.fit(
        X_seq,
        X,
        epochs=30,
        batch_size=32,
        verbose=1
    )

    model.save("cnn_attention_recommender.h5")

    print("✅ CNN + Attention recommender trained")

# ===============================
# PREPARE RECOMMENDATION DATA
# ===============================
def prepare_recommendation_data(df):
    print("\n--- PREPARING RECOMMENDATION DATA ---")

    df = df.dropna(subset=[
        'product_name', 'category',
        'product_price', 'overall_rating', 'sentiment_score'
    ])

    features = df[['overall_rating', 'sentiment_score', 'product_price']]
    scaler = MinMaxScaler()
    features_scaled = scaler.fit_transform(features)

    similarity_matrix = cosine_similarity(features_scaled)

    joblib.dump(df, "products_data.pkl")
    joblib.dump(similarity_matrix, "similarity_matrix.pkl")

    model_embed = SentenceTransformer('all-MiniLM-L6-v2')
    df['text'] = df['product_name'] + " " + df['category']
    embeddings = model_embed.encode(df['text'].tolist(), convert_to_tensor=True)

    joblib.dump(embeddings.cpu().numpy(), "product_embeddings.pkl")
    joblib.dump(model_embed, "embedding_model.pkl")

    print("✅ Recommendation data ready")


# ===============================
# RECOMMEND PRODUCTS
# ===============================
def recommend_products(user_input, top_n=5):

    df = joblib.load("products_data.pkl")
    embeddings = joblib.load("product_embeddings.pkl")
    model_embed = joblib.load("embedding_model.pkl")

    # 🔹 Load CNN model
    cnn_model = tf.keras.models.load_model("cnn_attention_recommender.h5")

    # 🔹 Prepare features
    df['neutral_distance'] = np.abs(df['overall_rating'] - 3)
    X = df[['overall_rating', 'neutral_distance']].values
    X = MinMaxScaler().fit_transform(X)
    X_seq = X.reshape((X.shape[0], X.shape[1], 1))

    # 🔹 CNN reconstruction error
    recon = cnn_model.predict(X_seq, verbose=0)
    recon_error = np.mean(np.square(X - recon), axis=1)
    df['dl_score'] = -recon_error

    # 🔹 Semantic similarity
    query_emb = model_embed.encode(user_input, convert_to_tensor=True)
    semantic_scores = cosine_similarity(
        query_emb.reshape(1, -1), embeddings
    )[0]

    # 🔹 Final hybrid score
    df['final_score'] = 0.7 * semantic_scores + 0.3 * df['dl_score'].values

    top_idx = df['final_score'].nlargest(top_n).index

    print(f"\n✅ Recommendations for '{user_input}':\n")

    for i in top_idx:
        p = df.loc[i]
        print(f"Product: {p['product_name']}")
        print(f"Category: {p['category']}")
        print(f"Rating: {p['overall_rating']} | Price: ₹{p['product_price']}")
        print("-" * 50)


# ===============================
# MAIN
# ===============================
if __name__ == "__main__":

    DATA_FOLDER = r"/content/beauty and care"

    df = load_datasets_from_folder(DATA_FOLDER)
    df = fill_and_encode_sentiment(df)

    # Clean price globally
    df['product_price'] = (
        df['product_price']
        .astype(str)
        .str.replace(r'[₹,\s]', '', regex=True)
    )
    df['product_price'] = pd.to_numeric(df['product_price'], errors='coerce')

    train_dl_sentiment_model(df)
    train_cnn_attention_recommender(df)
    prepare_recommendation_data(df)

    while True:
        name = input("\nEnter product name (or exit): ")
        if name.lower() == "exit":
            break
        recommend_products(name)
# Out:
# Loaded 600 records
#
# --- TRAINING DL SENTIMENT CLASSIFIER (BALANCED) ---
# Class weights: {0: np.float64(171.66666666666666), 1: np.float64(2.258771929824561), 2: np.float64(0.3919330289193303)}
# Epoch 1/30
# /tmp/ipython-input-4060446599.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['neutral_distance'] = np.abs(df['overall_rating'] - 3)
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8618 - loss: 0.7561
# Epoch 2/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8627 - loss: 1.8290
# Epoch 3/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8367 - loss: 0.8720
# Epoch 4/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8514 - loss: 0.7108
# Epoch 5/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8510 - loss: 0.7396
# Epoch 6/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8413 - loss: 1.0800
# Epoch 7/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8446 - loss: 1.4021
# Epoch 8/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8517 - loss: 0.9077
# Epoch 9/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8626 - loss: 0.6566
# Epoch 10/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8564 - loss: 0.6591
# Epoch 11/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8617 - loss: 0.8652
# Epoch 12/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8602 - loss: 0.7407
# Epoch 13/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8733 - loss: 0.7473
# Epoch 14/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8627 - loss: 0.6361
# Epoch 15/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8649 - loss: 0.6645
# Epoch 16/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8769 - loss: 0.6267
# Epoch 17/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8828 - loss: 0.5643
# Epoch 18/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8665 - loss: 0.5805
# Epoch 19/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9068 - loss: 0.7515
# Epoch 20/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8918 - loss: 0.5700
# Epoch 21/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8864 - loss: 0.7030
# Epoch 22/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8698 - loss: 0.5721
# Epoch 23/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8919 - loss: 0.7512
# Epoch 24/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9107 - loss: 0.7985
# Epoch 25/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8942 - loss: 0.7083
# Epoch 26/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9092 - loss: 0.9194
# Epoch 27/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9250 - loss: 0.5889
# Epoch 28/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9008 - loss: 0.7087
# Epoch 29/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8965 - loss: 0.5764
# Epoch 30/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9353 - loss: 0.5607
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
#
# 📊 DL Classification Report (Balanced):
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
#               precision    recall  f1-score   support
#
#     negative       1.00      1.00      1.00         1
#      neutral       1.00      0.29      0.45        76
#     positive       0.89      1.00      0.94       438
#
#     accuracy                           0.90       515
#    macro avg       0.96      0.76      0.80       515
# weighted avg       0.91      0.90      0.87       515
#
# ✅ DL sentiment model trained with class balancing
#
# --- TRAINING CNN + ATTENTION RECOMMENDER ---
# Epoch 1/30
# /tmp/ipython-input-4060446599.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['neutral_distance'] = np.abs(df['overall_rating'] - 3)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.3643
# Epoch 2/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0896
# Epoch 3/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0041
# Epoch 4/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0027
# Epoch 5/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.1294e-04
# Epoch 6/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.9215e-04
# Epoch 7/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.1698e-04
# Epoch 8/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.2753e-04
# Epoch 9/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.2564e-04
# Epoch 10/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5568e-04
# Epoch 11/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.1015e-04
# Epoch 12/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.3080e-04
# Epoch 13/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.8164e-04
# Epoch 14/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.2068e-04
# Epoch 15/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.8685e-04
# Epoch 16/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.5342e-04
# Epoch 17/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.9282e-04
# Epoch 18/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.3690e-04
# Epoch 19/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.1100e-04
# Epoch 20/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.1941e-04
# Epoch 21/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5674e-04
# Epoch 22/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.7570e-04
# Epoch 23/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.4955e-04
# Epoch 24/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6567e-04
# Epoch 25/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.2986e-05
# Epoch 26/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.0150e-04
# Epoch 27/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5945e-04
# Epoch 28/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.7656e-04
# Epoch 29/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7244e-05
# Epoch 30/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.5931e-04
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ✅ CNN + Attention recommender trained
#
# --- PREPARING RECOMMENDATION DATA ---
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# /tmp/ipython-input-4060446599.py:210: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['text'] = df['product_name'] + " " + df['category']
# ✅ Recommendation data ready
#
# Enter product name (or exit): eyeshadow
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# ✅ Recommendations for 'eyeshadow':
#
# Product: MINARA 60 Color Matte & Shimmery Pigment EyeShadow 170 ...
# Category: Beauty and Care
# Rating: 4.0 | Price: ₹189.0
# --------------------------------------------------
# Product: Hezruck 18 colour Nude Beauty Eyeshadow Platte
# Category: Beauty and Care
# Rating: 3.6 | Price: ₹153.0
# --------------------------------------------------
# Product: NYN Makeup Kit - Eye-Shadows, Lip Colors, Blushes, Spon...
# Category: Beauty and Care
# Rating: 3.7 | Price: ₹165.0
# --------------------------------------------------
# Product: NYN Makeup Kit - Eye-Shadows, Lip Colors, Blushes, Spon...
# Category: Beauty and Care
# Rating: 3.9 | Price: ₹164.0
# --------------------------------------------------
# Product: FACES CANADA Magneteyes Eye Makeup Combo - Black Eyelin...
# Category: Beauty and Care
# Rating: 4.3 | Price: ₹467.0
# --------------------------------------------------
#
# Enter product name (or exit): compact
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# ✅ Recommendations for 'compact':
#
# Product: Engage XX1 Cologne Eau de Cologne - 135 ml
# Category: Beauty and Care
# Rating: 4.2 | Price: ₹279.0
# --------------------------------------------------
# Product: Secret Temptation romance Eau de Parfum - 50 ml
# Category: Beauty and Care
# Rating: 4.2 | Price: ₹179.0
# --------------------------------------------------
# Product: Bath and Body Works DARK KISS COLLECTION
# Category: Beauty and Care
# Rating: 4.7 | Price: ₹5311.0
# --------------------------------------------------
# Product: Minimalist Dry_Skincare_Kit
# Category: Beauty and Care
# Rating: 4.2 | Price: ₹1197.0
# --------------------------------------------------
# Product: Iba Pure Skin Perfect Look Long-Wear Mattifying Compact...
# Category: Beauty and Care
# Rating: 3.9 | Price: ₹370.0
# --------------------------------------------------
#
# Enter product name (or exit): exit

# %% [markdown]
# # Electronics

# %%
# ===============================
# ELECTRONICS – AUTOENCODER VERSION
# ===============================

import pandas as pd
import numpy as np
import os
import glob
import joblib

from sklearn.preprocessing import MinMaxScaler, LabelEncoder
from sklearn.metrics import classification_report
from sklearn.metrics.pairwise import cosine_similarity

from sentence_transformers import SentenceTransformer

import tensorflow as tf
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.utils import to_categorical


# ===============================
# LOAD DATA
# ===============================
def load_datasets_from_folder(folder_path):
    all_files = glob.glob(os.path.join(folder_path, "*.csv"))
    if not all_files:
        raise Exception("No CSV files found!")

    df = pd.concat([pd.read_csv(f) for f in all_files], ignore_index=True)
    print(f"Loaded {len(df)} records")
    return df


# ===============================
# SENTIMENT PREPROCESSING
# ===============================
def fill_and_encode_sentiment(df):

    def rating_to_sentiment(r):
        if pd.isna(r):
            return 'neutral'
        elif r >= 4:
            return 'positive'
        elif r >= 3:
            return 'neutral'
        else:
            return 'negative'

    df['sentiment'] = df['sentiment'].fillna(
        df['overall_rating'].apply(rating_to_sentiment)
    )

    df['sentiment'] = df['sentiment'].str.lower().str.strip()

    sentiment_map = {'negative': 0, 'neutral': 1, 'positive': 2}
    df['sentiment_score'] = df['sentiment'].map(sentiment_map)

    return df


# ===============================
# DL SENTIMENT CLASSIFIER
# ===============================
def train_dl_sentiment_model(df):
    print("\n--- TRAINING DL SENTIMENT CLASSIFIER (BALANCED) ---")

    df = df.dropna(subset=['overall_rating', 'sentiment_score'])

    X = df[['overall_rating']].values
    y = df['sentiment_score'].values

    scaler = MinMaxScaler()
    X = scaler.fit_transform(X)

    y_cat = tf.keras.utils.to_categorical(y, num_classes=3)

    # 🔹 COMPUTE CLASS WEIGHTS
    class_counts = np.bincount(y)
    total = len(y)

    class_weights = {
        i: total / (3 * count) for i, count in enumerate(class_counts)
    }

    print("Class weights:", class_weights)

    # 🔹 DL MODEL
    model = tf.keras.Sequential([
        Dense(32, activation='relu', input_shape=(1,)),
        Dense(16, activation='relu'),
        Dense(3, activation='softmax')
    ])

    model.compile(
        optimizer='adam',
        loss='categorical_crossentropy',
        metrics=['accuracy']
    )

    model.fit(
        X,
        y_cat,
        epochs=30,
        batch_size=32,
        class_weight=class_weights,
        verbose=1
    )

    # 🔹 EVALUATION
    y_pred = model.predict(X)
    y_pred_labels = np.argmax(y_pred, axis=1)

    print("\n📊 DL Classification Report (Balanced):\n")
    print(classification_report(
        y,
        y_pred_labels,
        target_names=['negative', 'neutral', 'positive'],
        zero_division=0
    ))

    model.save("dl_sentiment_model.h5")
    joblib.dump(scaler, "dl_sentiment_scaler.pkl")

    print("✅ DL sentiment model trained with class balancing")


# ===============================
# AUTOENCODER RECOMMENDER (DL)
# ===============================
def train_autoencoder_recommender(df):
    print("\n--- TRAINING AUTOENCODER RECOMMENDER ---")

    df = df.dropna(subset=['overall_rating', 'sentiment_score', 'product_price'])

    X = df[['overall_rating', 'sentiment_score', 'product_price']].values
    X = MinMaxScaler().fit_transform(X)

    input_layer = Input(shape=(3,))
    encoded = Dense(16, activation='relu')(input_layer)
    encoded = Dense(8, activation='relu')(encoded)
    decoded = Dense(3, activation='linear')(encoded)

    autoencoder = Model(input_layer, decoded)
    autoencoder.compile(
        optimizer='adam',
        loss=tf.keras.losses.MeanSquaredError()
    )

    autoencoder.fit(X, X, epochs=30, batch_size=32, verbose=1)
    autoencoder.save("ae_recommender.h5")

    print("✅ Autoencoder trained")


# ===============================
# PREPARE RECOMMENDATION DATA
# ===============================
def prepare_recommendation_data(df):
    print("\n--- PREPARING RECOMMENDATION DATA ---")

    df = df.dropna(subset=[
        'product_name', 'category',
        'product_price', 'overall_rating', 'sentiment_score'
    ])

    features = df[['overall_rating', 'sentiment_score', 'product_price']]
    scaler = MinMaxScaler()
    features_scaled = scaler.fit_transform(features)

    similarity_matrix = cosine_similarity(features_scaled)

    joblib.dump(df, "products_data.pkl")
    joblib.dump(similarity_matrix, "similarity_matrix.pkl")

    model_embed = SentenceTransformer('all-MiniLM-L6-v2')
    df['text'] = df['product_name'] + " " + df['category']
    embeddings = model_embed.encode(df['text'].tolist(), convert_to_tensor=True)

    joblib.dump(embeddings.cpu().numpy(), "product_embeddings.pkl")
    joblib.dump(model_embed, "embedding_model.pkl")

    print("✅ Recommendation data ready")


# ===============================
# RECOMMEND PRODUCTS
# ===============================
def recommend_products(user_input, top_n=5):

    df = joblib.load("products_data.pkl")
    embeddings = joblib.load("product_embeddings.pkl")
    model_embed = joblib.load("embedding_model.pkl")

    query_emb = model_embed.encode(user_input, convert_to_tensor=True)
    scores = cosine_similarity(query_emb.reshape(1, -1), embeddings)[0]

    top_idx = np.argsort(scores)[::-1][:top_n]

    print(f"\n✅ Recommendations for '{user_input}':\n")

    for i in top_idx:
        p = df.iloc[i]
        print(f"Product: {p['product_name']}")
        print(f"Category: {p['category']}")
        print(f"Rating: {p['overall_rating']} | Price: ₹{p['product_price']}")
        print("-" * 50)


# ===============================
# MAIN
# ===============================
if __name__ == "__main__":

    DATA_FOLDER = r"/content/electronics"

    df = load_datasets_from_folder(DATA_FOLDER)
    df = fill_and_encode_sentiment(df)

    # Clean price globally
    df['product_price'] = (
        df['product_price']
        .astype(str)
        .str.replace(r'[₹,\s]', '', regex=True)
    )
    df['product_price'] = pd.to_numeric(df['product_price'], errors='coerce')

    train_dl_sentiment_model(df)
    train_autoencoder_recommender(df)
    prepare_recommendation_data(df)

    while True:
        name = input("\nEnter product name (or exit): ")
        if name.lower() == "exit":
            break
        recommend_products(name)
# Out:
# Loaded 500 records
#
# --- TRAINING DL SENTIMENT CLASSIFIER (BALANCED) ---
# Class weights: {0: np.float64(166.66666666666666), 1: np.float64(3.9682539682539684), 2: np.float64(0.36469730123997085)}
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.0000e+00 - loss: 1.2709
# Epoch 2/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0000e+00 - loss: 0.8887
# Epoch 3/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.1448 - loss: 0.7710
# Epoch 4/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9084 - loss: 1.0018
# Epoch 5/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9559 - loss: 0.7427
# Epoch 6/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9325 - loss: 1.3383
# Epoch 7/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9225 - loss: 1.0047
# Epoch 8/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9368 - loss: 0.9155
# Epoch 9/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9421 - loss: 0.9738
# Epoch 10/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9322 - loss: 0.6974
# Epoch 11/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9331 - loss: 0.8405
# Epoch 12/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9418 - loss: 0.7479
# Epoch 13/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8829 - loss: 0.8460
# Epoch 14/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9695 - loss: 0.8253
# Epoch 15/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9425 - loss: 1.7502
# Epoch 16/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9236 - loss: 1.2425
# Epoch 17/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9110 - loss: 0.7490
# Epoch 18/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9283 - loss: 0.7384
# Epoch 19/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9126 - loss: 1.2273
# Epoch 20/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8987 - loss: 0.8692
# Epoch 21/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9236 - loss: 0.9367
# Epoch 22/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8990 - loss: 1.2003
# Epoch 23/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9145 - loss: 0.5547
# Epoch 24/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8949 - loss: 0.6526
# Epoch 25/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9173 - loss: 0.5967
# Epoch 26/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9165 - loss: 1.2474
# Epoch 27/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9268 - loss: 0.9434
# Epoch 28/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9123 - loss: 0.6432
# Epoch 29/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9273 - loss: 0.7901
# Epoch 30/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9264 - loss: 0.7499
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
#
# 📊 DL Classification Report (Balanced):
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
#               precision    recall  f1-score   support
#
#     negative       1.00      1.00      1.00         1
#      neutral       1.00      0.10      0.17        42
#     positive       0.92      1.00      0.96       457
#
#     accuracy                           0.92       500
#    macro avg       0.97      0.70      0.71       500
# weighted avg       0.93      0.92      0.89       500
#
# ✅ DL sentiment model trained with class balancing
#
# --- TRAINING AUTOENCODER RECOMMENDER ---
# Epoch 1/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5180
# Epoch 2/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4429
# Epoch 3/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4047
# Epoch 4/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3505
# Epoch 5/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2996
# Epoch 6/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2442
# Epoch 7/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1900
# Epoch 8/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1408
# Epoch 9/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0994
# Epoch 10/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0712
# Epoch 11/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0477
# Epoch 12/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0310
# Epoch 13/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0206
# Epoch 14/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0143
# Epoch 15/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0100
# Epoch 16/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0083
# Epoch 17/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0072
# Epoch 18/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0068
# Epoch 19/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0060
# Epoch 20/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0057
# Epoch 21/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0056
# Epoch 22/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0051
# Epoch 23/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0057
# Epoch 24/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0055
# Epoch 25/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0047
# Epoch 26/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0047
# Epoch 27/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0041
# Epoch 28/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0045
# Epoch 29/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0043
# Epoch 30/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0043
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ✅ Autoencoder trained
#
# --- PREPARING RECOMMENDATION DATA ---
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# ✅ Recommendation data ready
#
# Enter product name (or exit): tv
#
# ✅ Recommendations for 'tv':
#
# Product: Add to Compare
# BESTON 80 cm (32 inch) HD Ready LED Smart Android TV 2025 Edition
# 3.94,925 Ratings & 616 Reviews
# HD Ready | LED
# Model ID: BS32HD1
# Launch Year: 2025
# Total Sound Output: 20 W
# 2 Year warranty on Product , Onsite Warranty on Product and No Delivery Damages Covered
# ₹7,359
# ₹17,99959% off
# Hot Deal
# Upto
# ₹1,900
#  Off on Exchange
# Category: Electronics
# Rating: 3.9 | Price: ₹7359
# --------------------------------------------------
# Product: Add to Compare
# iFFALCON by TCL S55 80 cm (32 inch) HD Ready LED Smart Google TV 2025 Edition with HDR 10 | 16W Dolby ...
# 4.16,693 Ratings & 443 Reviews
# HD Ready | LED
# Model ID: 32S55
# Launch Year: 2025
# Total Sound Output: 16 W
# 1 Year Product Warranty
# ₹8,799
# ₹19,99055% off
# Upto
# ₹1,900
#  Off on Exchange
# Bank Offer
# Category: Electronics
# Rating: 4.1 | Price: ₹8799
# --------------------------------------------------
# Product: Add to Compare
# KODAK Special Edition 108 cm (43 inch) Full HD LED Smart Linux TV with 30W Sound Output & Bezel-Less D...
# 4.113,413 Ratings & 1,309 Reviews
# Full HD | LED
# Model ID: 43SE5004BL
# Launch Year: 2024
# Total Sound Output: 30 W
# 1 Year Warranty on Product and 6 Months Warranty on Accessories
# ₹13,999
# ₹20,99933% off
# Upto
# ₹1,900
#  Off on Exchange
# Bank Offer
# Category: Electronics
# Rating: 4.1 | Price: ₹13999
# --------------------------------------------------
# Product: Add to Compare
# PHILIPS Frameless 80 cm (32 inch) HD Ready LED Smart Google TV 2025 Edition with Dolby Audio|24W RMS S...
# 4.15,319 Ratings & 466 Reviews
# HD Ready | LED
# Model ID: 32PFT6130/94
# Launch Year: 2025
# Total Sound Output: 24 W
# 1 Year Domestic Warranty
# ₹10,999
# ₹22,99952% off
# Hot Deal
# Upto
# ₹1,900
#  Off on Exchange
# Category: Electronics
# Rating: 4.1 | Price: ₹10999
# --------------------------------------------------
# Product: Add to Compare
# Foxsky 60 cm (24 inch) HD Ready LED TV
# 45,464 Ratings & 655 Reviews
# HD Ready | LED
# Model ID: 24FSN
# Launch Year: 2023
# Total Sound Output: 30 W
# 1-Year Foxsky Standard Warranty on Product from the date of purchase
# ₹4,999
# ₹12,99961% off
# Upto
# ₹1,900
#  Off on Exchange
# Bank Offer
# Category: Electronics
# Rating: 4.0 | Price: ₹4999
# --------------------------------------------------
#
# Enter product name (or exit): ac
#
# ✅ Recommendations for 'ac':
#
# Product: Add to Compare
# Mitsubishi Electric 2024 Model 1.5 Ton 2 Star Split AC
# 3.815 Ratings & 0 Reviews
# Annual Power Usage: 1122.45 Units
# Room Size: 111 - 150 sqft
# 1
# ₹36,990
# ₹49,00024% off
# Hot Deal
# Only 1 left
# Category: Electronics
# Rating: 3.8 | Price: ₹36990
# --------------------------------------------------
# Product: Add to Compare
# Lloyd 2023 Model 2 Ton 3 Star Split Inverter AC
# 3.9614 Ratings & 51 Reviews
# Annual Power Usage: 1261.37 Units
# Room Size: 151 - 200 sqft
# 1 Year Comprehensive Warranty on Product and 10 Years Warranty on Compressor
# ₹37,890
# ₹77,99051% off
# Hot Deal
# Upto
# ₹3,500
#  Off on Exchange
# Category: Electronics
# Rating: 3.9 | Price: ₹37890
# --------------------------------------------------
# Product: Add to Compare
# Mitsubishi Electric 2025 Model 1 Ton 3 Star Split AC
# 2.58 Ratings & 1 Reviews
# Annual Power Usage: 675.02 kWh
# Room Size: 90 sqft or Below
# ₹31,380
# ₹44,00028% off
# Hot Deal
# Only 2 left
# Category: Electronics
# Rating: 2.5 | Price: ₹31380
# --------------------------------------------------
# Product: Add to Compare
# Samsung 2025 Model 1.5 Ton 3 Star Split Inverter with Wi-fi AC
# 4.135,217 Ratings & 3,227 Reviews
# Annual Power Usage: 852.47 W
# Room Size: 111 - 150 sqft
# 5 Years Comprehensive Warranty on AC and 10 Years Warranty on Compressor
# ₹32,490
# ₹72,79055% off
# Upto
# ₹3,500
#  Off on Exchange
# Bank Offer
# Category: Electronics
# Rating: 4.1 | Price: ₹32490
# --------------------------------------------------
# Product: Add to Compare
# Blue Star 2025 Model 1 Ton Portable AC
# 3.74,719 Ratings & 631 Reviews
# Room Size: 90 sqft or Below
# 1 Year Warranty on product, 5 Year Warranty on Compressor.
# ₹30,900
# ₹39,00020% off
# Only few left
# Bank Offer
# Category: Electronics
# Rating: 3.7 | Price: ₹30900
# --------------------------------------------------
#
# Enter product name (or exit): refigerator
#
# ✅ Recommendations for 'refigerator':
#
# Product: Add to Compare
# Whirlpool 192 L Direct Cool Single Door 4 Star Refrigerator with Base Drawer
# 4.632 Ratings & 4 Reviews
# Inverter
# Built-in Stabilizer
# 1 Year Comprehensive Warranty + 9 Years Warranty on Compressor
# ₹17,470
# ₹24,15027% off
# Hot Deal
# Only 5 left
# Category: Electronics
# Rating: 4.6 | Price: ₹17470
# --------------------------------------------------
# Product: Add to Compare
# Voltas Beko 183 L Direct Cool Single Door 2 Star Refrigerator
# 4.311,641 Ratings & 714 Reviews
# Reciprocating Compressor
# Built-in Stabilizer
# 1 Year Comprehensive Warranty on Product and 10 Years Warranty on Compressor
# ₹11,990
# ₹25,99053% off
# Hot Deal
# Upto
# ₹3,770
#  Off on Exchange
# Category: Electronics
# Rating: 4.3 | Price: ₹11990
# --------------------------------------------------
# Product: Bestseller
# Add to Compare
# Godrej 180 L Direct Cool Single Door 2 Star Refrigerator with Farm Fresh Crisper Technology | Jumbo V...
# 4.316,235 Ratings & 822 Reviews
# Reciprocatory Compressor
# Built-in Stabilizer
# 1 Year Comprehensive Warranty on Product and 10 Years on Compressor
# ₹11,990
# ₹16,99029% off
# Hot Deal
# Upto
# ₹6,570
#  Off on Exchange
# Category: Electronics
# Rating: 4.3 | Price: ₹11990
# --------------------------------------------------
# Product: Add to Compare
# BOSCH 187 L Direct Cool Single Door 5 Star Refrigerator with Base Drawer with Industry's largest vege...
# 4.6180 Ratings & 17 Reviews
# Reciprocating Compressor
# Built-in Stabilizer
# 1 year comprehensive product warranty Plus 10 years compressor warranty
# ₹19,767
# ₹26,29024% off
# Only 5 left
# Bank Offer
# Category: Electronics
# Rating: 4.6 | Price: ₹19767
# --------------------------------------------------
# Product: Add to Compare
# Whirlpool 192 L Direct Cool Single Door 4 Star Refrigerator with Base Drawer
# 4.425,603 Ratings & 1,666 Reviews
# Inverter Compressor
# Built-in Stabilizer
# 1 Year Comprehensive Warranty on Product and 9 Years Warranty on Compressor
# ₹16,240
# ₹21,95026% off
# Hot Deal
# Upto
# ₹6,570
#  Off on Exchange
# Category: Electronics
# Rating: 4.4 | Price: ₹16240
# --------------------------------------------------
#
# Enter product name (or exit): mobile
#
# ✅ Recommendations for 'mobile':
#
# Product: 5. Samsung Galaxy A35 5G (Awes...
# 4.471,218 Ratings&4,146 Reviews
# ₹19,99941% off
# Category: Electronics
# Rating: 4.4 | Price: ₹19999
# --------------------------------------------------
# Product: 3. Samsung Galaxy S24 5G Snapd...
# 4.652,392 Ratings&2,872 Reviews
# ₹44,99940% off
# Category: Electronics
# Rating: 4.6 | Price: ₹44999
# --------------------------------------------------
# Product: 3. MOTOROLA Edge 60 Fusion 5G ...
# 4.41,19,764 Ratings&6,185 Reviews
# ₹21,99915% off
# Category: Electronics
# Rating: 4.4 | Price: ₹21999
# --------------------------------------------------
# Product: 5. MOTOROLA g35 5G (Leaf Green...
# 4.21,22,684 Ratings&7,499 Reviews
# ₹10,99912% off
# Category: Electronics
# Rating: 4.2 | Price: ₹10999
# --------------------------------------------------
# Product: 1. MOTOROLA Edge 60 Fusion 5G ...
# 4.41,19,764 Ratings&6,185 Reviews
# ₹21,99915% off
# Category: Electronics
# Rating: 4.4 | Price: ₹21999
# --------------------------------------------------
#
# Enter product name (or exit): exit

# %%
# ===============================
# ELECTRONICS – LSTM VERSION
# ===============================

import pandas as pd
import numpy as np
import os
import glob
import joblib

from sklearn.preprocessing import MinMaxScaler, LabelEncoder
from sklearn.metrics import classification_report
from sklearn.metrics.pairwise import cosine_similarity

from sentence_transformers import SentenceTransformer

import tensorflow as tf
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import LSTM, Attention, Reshape, Flatten


# ===============================
# LOAD DATA
# ===============================
def load_datasets_from_folder(folder_path):
    all_files = glob.glob(os.path.join(folder_path, "*.csv"))
    if not all_files:
        raise Exception("No CSV files found!")

    df = pd.concat([pd.read_csv(f) for f in all_files], ignore_index=True)
    print(f"Loaded {len(df)} records")
    return df


# ===============================
# SENTIMENT PREPROCESSING
# ===============================
def fill_and_encode_sentiment(df):

    def rating_to_sentiment(r):
        if pd.isna(r):
            return 'neutral'
        elif r >= 4:
            return 'positive'
        elif r >= 3:
            return 'neutral'
        else:
            return 'negative'

    df['sentiment'] = df['sentiment'].fillna(
        df['overall_rating'].apply(rating_to_sentiment)
    )

    df['sentiment'] = df['sentiment'].str.lower().str.strip()

    sentiment_map = {'negative': 0, 'neutral': 1, 'positive': 2}
    df['sentiment_score'] = df['sentiment'].map(sentiment_map)

    return df


# ===============================
# DL SENTIMENT CLASSIFIER
# ===============================
def train_dl_sentiment_model(df):
    print("\n--- TRAINING DL SENTIMENT CLASSIFIER (BALANCED) ---")

    df = df.dropna(subset=['overall_rating', 'sentiment_score'])

    X = df[['overall_rating']].values
    y = df['sentiment_score'].values

    scaler = MinMaxScaler()
    X = scaler.fit_transform(X)

    y_cat = tf.keras.utils.to_categorical(y, num_classes=3)

    # 🔹 COMPUTE CLASS WEIGHTS
    class_counts = np.bincount(y)
    total = len(y)

    class_weights = {
        i: total / (3 * count) for i, count in enumerate(class_counts)
    }

    print("Class weights:", class_weights)

    # 🔹 DL MODEL
    model = tf.keras.Sequential([
        Dense(32, activation='relu', input_shape=(1,)),
        Dense(16, activation='relu'),
        Dense(3, activation='softmax')
    ])

    model.compile(
        optimizer='adam',
        loss='categorical_crossentropy',
        metrics=['accuracy']
    )

    model.fit(
        X,
        y_cat,
        epochs=30,
        batch_size=32,
        class_weight=class_weights,
        verbose=1
    )

    # 🔹 EVALUATION
    y_pred = model.predict(X)
    y_pred_labels = np.argmax(y_pred, axis=1)

    print("\n📊 DL Classification Report (Balanced):\n")
    print(classification_report(
        y,
        y_pred_labels,
        target_names=['negative', 'neutral', 'positive'],
        zero_division=0
    ))

    model.save("dl_sentiment_model.h5")
    joblib.dump(scaler, "dl_sentiment_scaler.pkl")

    print("✅ DL sentiment model trained with class balancing")


# ===============================
# LSTM + ATTENTION RECOMMENDER (DL)
# ===============================
def train_lstm_attention_recommender(df):
    print("\n--- TRAINING LSTM + ATTENTION RECOMMENDER ---")

    df = df.dropna(subset=['overall_rating', 'sentiment_score', 'product_price'])

    # 🔹 Feature matrix
    X = df[['overall_rating', 'sentiment_score', 'product_price']].values
    X = MinMaxScaler().fit_transform(X)

    # 🔹 Convert to sequence format (timesteps = features)
    # Shape: (samples, timesteps, features_per_step)
    X_seq = X.reshape((X.shape[0], X.shape[1], 1))

    # 🔹 INPUT
    input_layer = Input(shape=(X_seq.shape[1], 1))

    # 🔹 LSTM
    lstm_out = LSTM(64, return_sequences=True)(input_layer)

    # 🔹 ATTENTION
    attention_out = Attention()([lstm_out, lstm_out])

    # 🔹 FLATTEN
    flat = Flatten()(attention_out)

    # 🔹 OUTPUT (reconstruct input features)
    output_layer = Dense(X.shape[1], activation='linear')(flat)

    # 🔹 MODEL
    model = Model(inputs=input_layer, outputs=output_layer)

    model.compile(
        optimizer='adam',
        loss=tf.keras.losses.MeanSquaredError()
    )

    model.fit(
        X_seq,
        X,
        epochs=30,
        batch_size=32,
        verbose=1
    )

    model.save("lstm_attention_recommender.h5")

    print("✅ LSTM + Attention recommender trained")

# ===============================
# PREPARE RECOMMENDATION DATA
# ===============================
def prepare_recommendation_data(df):
    print("\n--- PREPARING RECOMMENDATION DATA ---")

    df = df.dropna(subset=[
        'product_name', 'category',
        'product_price', 'overall_rating', 'sentiment_score'
    ])

    features = df[['overall_rating', 'sentiment_score', 'product_price']]
    scaler = MinMaxScaler()
    features_scaled = scaler.fit_transform(features)

    similarity_matrix = cosine_similarity(features_scaled)

    joblib.dump(df, "products_data.pkl")
    joblib.dump(similarity_matrix, "similarity_matrix.pkl")

    model_embed = SentenceTransformer('all-MiniLM-L6-v2')
    df['text'] = df['product_name'] + " " + df['category']
    embeddings = model_embed.encode(df['text'].tolist(), convert_to_tensor=True)

    joblib.dump(embeddings.cpu().numpy(), "product_embeddings.pkl")
    joblib.dump(model_embed, "embedding_model.pkl")

    print("✅ Recommendation data ready")


# ===============================
# RECOMMEND PRODUCTS
# ===============================
def recommend_products(user_input, top_n=5):

    df = joblib.load("products_data.pkl")
    embeddings = joblib.load("product_embeddings.pkl")
    model_embed = joblib.load("embedding_model.pkl")

    query_emb = model_embed.encode(user_input, convert_to_tensor=True)
    scores = cosine_similarity(query_emb.reshape(1, -1), embeddings)[0]

    top_idx = np.argsort(scores)[::-1][:top_n]

    print(f"\n✅ Recommendations for '{user_input}':\n")

    for i in top_idx:
        p = df.iloc[i]
        print(f"Product: {p['product_name']}")
        print(f"Category: {p['category']}")
        print(f"Rating: {p['overall_rating']} | Price: ₹{p['product_price']}")
        print("-" * 50)


# ===============================
# MAIN
# ===============================
if __name__ == "__main__":

    DATA_FOLDER = r"/content/beauty and care"

    df = load_datasets_from_folder(DATA_FOLDER)
    df = fill_and_encode_sentiment(df)

    # Clean price globally
    df['product_price'] = (
        df['product_price']
        .astype(str)
        .str.replace(r'[₹,\s]', '', regex=True)
    )
    df['product_price'] = pd.to_numeric(df['product_price'], errors='coerce')

    train_dl_sentiment_model(df)
    train_lstm_attention_recommender(df)
    prepare_recommendation_data(df)

    while True:
        name = input("\nEnter product name (or exit): ")
        if name.lower() == "exit":
            break
        recommend_products(name)
# Out:
# Loaded 600 records
#
# --- TRAINING DL SENTIMENT CLASSIFIER (BALANCED) ---
# Class weights: {0: np.float64(171.66666666666666), 1: np.float64(2.258771929824561), 2: np.float64(0.3919330289193303)}
# Epoch 1/30
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.1157 - loss: 0.8671
# Epoch 2/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8531 - loss: 1.1773
# Epoch 3/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8392 - loss: 1.5377
# Epoch 4/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8563 - loss: 1.0599
# Epoch 5/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8450 - loss: 0.8491
# Epoch 6/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8327 - loss: 1.1368
# Epoch 7/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8396 - loss: 0.8565
# Epoch 8/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8530 - loss: 0.7471
# Epoch 9/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8530 - loss: 0.9158
# Epoch 10/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8368 - loss: 1.3969
# Epoch 11/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8488 - loss: 1.3577
# Epoch 12/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8514 - loss: 0.7194
# Epoch 13/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8608 - loss: 0.6064
# Epoch 14/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8714 - loss: 0.6257
# Epoch 15/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8543 - loss: 0.7444
# Epoch 16/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8371 - loss: 0.5861
# Epoch 17/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8292 - loss: 0.5930
# Epoch 18/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8467 - loss: 0.9248
# Epoch 19/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8510 - loss: 0.6285
# Epoch 20/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8722 - loss: 0.5843
# Epoch 21/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8580 - loss: 0.7721
# Epoch 22/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8546 - loss: 0.7725
# Epoch 23/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8648 - loss: 0.6119
# Epoch 24/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8666 - loss: 0.6326
# Epoch 25/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8747 - loss: 1.1257
# Epoch 26/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8597 - loss: 0.7424
# Epoch 27/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8661 - loss: 0.7714
# Epoch 28/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8465 - loss: 0.6817
# Epoch 29/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8624 - loss: 0.6856
# Epoch 30/30
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8468 - loss: 0.7863
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 📊 DL Classification Report (Balanced):
#
#               precision    recall  f1-score   support
#
#     negative       1.00      1.00      1.00         1
#      neutral       0.00      0.00      0.00        76
#     positive       0.85      1.00      0.92       438
#
#     accuracy                           0.85       515
#    macro avg       0.62      0.67      0.64       515
# weighted avg       0.73      0.85      0.78       515
#
# ✅ DL sentiment model trained with class balancing
#
# --- TRAINING LSTM + ATTENTION RECOMMENDER ---
# Epoch 1/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.4471
# Epoch 2/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2509
# Epoch 3/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0572
# Epoch 4/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0131
# Epoch 5/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0055
# Epoch 6/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0047
# Epoch 7/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0047
# Epoch 8/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0041
# Epoch 9/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0047
# Epoch 10/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0047
# Epoch 11/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0043
# Epoch 12/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0050
# Epoch 13/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0049
# Epoch 14/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0044
# Epoch 15/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0057
# Epoch 16/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0043
# Epoch 17/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0049
# Epoch 18/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0047
# Epoch 19/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0041
# Epoch 20/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0049
# Epoch 21/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0042
# Epoch 22/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0037
# Epoch 23/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0043
# Epoch 24/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0041
# Epoch 25/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0034
# Epoch 26/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0039
# Epoch 27/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0043
# Epoch 28/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0040
# Epoch 29/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0048
# Epoch 30/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0039
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ✅ LSTM + Attention recommender trained
#
# --- PREPARING RECOMMENDATION DATA ---
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# /tmp/ipython-input-2482332218.py:202: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['text'] = df['product_name'] + " " + df['category']
# ✅ Recommendation data ready
#
# Enter product name (or exit): exit

# %%
# ===============================
# ELECTRONICS - CNN VERSION
# ===============================

import pandas as pd
import numpy as np
import os
import glob
import joblib

from sklearn.preprocessing import MinMaxScaler, LabelEncoder
from sklearn.metrics import classification_report
from sklearn.metrics.pairwise import cosine_similarity

from sentence_transformers import SentenceTransformer

import tensorflow as tf
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Conv1D, GlobalAveragePooling1D
from tensorflow.keras.layers import Attention, Reshape


# ===============================
# LOAD DATA
# ===============================
def load_datasets_from_folder(folder_path):
    all_files = glob.glob(os.path.join(folder_path, "*.csv"))
    if not all_files:
        raise Exception("No CSV files found!")

    df = pd.concat([pd.read_csv(f) for f in all_files], ignore_index=True)
    print(f"Loaded {len(df)} records")
    return df


# ===============================
# SENTIMENT PREPROCESSING
# ===============================
def fill_and_encode_sentiment(df):

    def rating_to_sentiment(r):
        if pd.isna(r):
            return 'neutral'
        elif r >= 4:
            return 'positive'
        elif r >= 3:
            return 'neutral'
        else:
            return 'negative'

    df['sentiment'] = df['sentiment'].fillna(
        df['overall_rating'].apply(rating_to_sentiment)
    )

    df['sentiment'] = df['sentiment'].str.lower().str.strip()

    sentiment_map = {'negative': 0, 'neutral': 1, 'positive': 2}
    df['sentiment_score'] = df['sentiment'].map(sentiment_map)

    return df


# ===============================
# DL SENTIMENT CLASSIFIER
# ===============================
def train_dl_sentiment_model(df):
    print("\n--- TRAINING DL SENTIMENT CLASSIFIER (BALANCED) ---")

    df = df.dropna(subset=['overall_rating', 'sentiment_score'])

    df['neutral_distance'] = np.abs(df['overall_rating'] - 3)

    X = df[['overall_rating', 'neutral_distance']].values

    y = df['sentiment_score'].values

    scaler = MinMaxScaler()
    X = scaler.fit_transform(X)

    y_cat = tf.keras.utils.to_categorical(y, num_classes=3)

    # 🔹 COMPUTE CLASS WEIGHTS
    class_counts = np.bincount(y)
    total = len(y)

    class_weights = {
        i: total / (3 * count) for i, count in enumerate(class_counts)
    }

    print("Class weights:", class_weights)

    # 🔹 DL MODEL
    model = tf.keras.Sequential([
        Dense(32, activation='relu', input_shape=(2,)),
        Dense(16, activation='relu'),
        Dense(3, activation='softmax')
    ])

    model.compile(
        optimizer='adam',
        loss=tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.1),
        metrics=['accuracy']
    )

    model.fit(
        X,
        y_cat,
        epochs=30,
        batch_size=32,
        class_weight=class_weights,
        verbose=1
    )

    # 🔹 EVALUATION
    y_pred = model.predict(X)
    y_pred_labels = np.argmax(y_pred, axis=1)

    print("\n📊 DL Classification Report (Balanced):\n")
    print(classification_report(
        y,
        y_pred_labels,
        target_names=['negative', 'neutral', 'positive'],
        zero_division=0
    ))

    model.save("dl_sentiment_model.h5")
    joblib.dump(scaler, "dl_sentiment_scaler.pkl")

    print("✅ DL sentiment model trained with class balancing")


# ===============================
# CNN + ATTENTION RECOMMENDER (DL)
# ===============================
def train_cnn_attention_recommender(df):
    print("\n--- TRAINING CNN + ATTENTION RECOMMENDER ---")

    df = df.dropna(subset=['overall_rating', 'sentiment_score', 'product_price'])

    # 🔹 Feature matrix
    df['neutral_distance'] = np.abs(df['overall_rating'] - 3)

    X = df[['overall_rating', 'neutral_distance']].values

    X = MinMaxScaler().fit_transform(X)

    # 🔹 Reshape for CNN
    # Shape: (samples, timesteps, channels)
    X_seq = X.reshape((X.shape[0], X.shape[1], 1))

    # 🔹 INPUT
    input_layer = Input(shape=(X_seq.shape[1], 1))

    # 🔹 CNN layers
    conv1 = Conv1D(filters=64, kernel_size=2, activation='relu', padding='same')(input_layer)
    conv2 = Conv1D(filters=32, kernel_size=2, activation='relu', padding='same')(conv1)

    # 🔹 ATTENTION
    attention_out = Attention()([conv2, conv2])

    # 🔹 POOLING
    pooled = GlobalAveragePooling1D()(attention_out)

    # 🔹 OUTPUT (reconstruction)
    output_layer = Dense(X.shape[1], activation='linear')(pooled)

    # 🔹 MODEL
    model = Model(inputs=input_layer, outputs=output_layer)

    model.compile(
        optimizer='adam',
        loss=tf.keras.losses.MeanSquaredError()
    )

    model.fit(
        X_seq,
        X,
        epochs=30,
        batch_size=32,
        verbose=1
    )

    model.save("cnn_attention_recommender.h5")

    print("✅ CNN + Attention recommender trained")

# ===============================
# PREPARE RECOMMENDATION DATA
# ===============================
def prepare_recommendation_data(df):
    print("\n--- PREPARING RECOMMENDATION DATA ---")

    df = df.dropna(subset=[
        'product_name', 'category',
        'product_price', 'overall_rating', 'sentiment_score'
    ])

    features = df[['overall_rating', 'sentiment_score', 'product_price']]
    scaler = MinMaxScaler()
    features_scaled = scaler.fit_transform(features)

    similarity_matrix = cosine_similarity(features_scaled)

    joblib.dump(df, "products_data.pkl")
    joblib.dump(similarity_matrix, "similarity_matrix.pkl")

    model_embed = SentenceTransformer('all-MiniLM-L6-v2')
    df['text'] = df['product_name'] + " " + df['category']
    embeddings = model_embed.encode(df['text'].tolist(), convert_to_tensor=True)

    joblib.dump(embeddings.cpu().numpy(), "product_embeddings.pkl")
    joblib.dump(model_embed, "embedding_model.pkl")

    print("✅ Recommendation data ready")


# ===============================
# RECOMMEND PRODUCTS
# ===============================
def recommend_products(user_input, top_n=5):

    df = joblib.load("products_data.pkl")
    embeddings = joblib.load("product_embeddings.pkl")
    model_embed = joblib.load("embedding_model.pkl")

    # 🔹 Load CNN model
    cnn_model = tf.keras.models.load_model("cnn_attention_recommender.h5")

    # 🔹 Prepare features
    df['neutral_distance'] = np.abs(df['overall_rating'] - 3)
    X = df[['overall_rating', 'neutral_distance']].values
    X = MinMaxScaler().fit_transform(X)
    X_seq = X.reshape((X.shape[0], X.shape[1], 1))

    # 🔹 CNN reconstruction error
    recon = cnn_model.predict(X_seq, verbose=0)
    recon_error = np.mean(np.square(X - recon), axis=1)
    df['dl_score'] = -recon_error

    # 🔹 Semantic similarity
    query_emb = model_embed.encode(user_input, convert_to_tensor=True)
    semantic_scores = cosine_similarity(
        query_emb.reshape(1, -1), embeddings
    )[0]

    # 🔹 Final hybrid score
    df['final_score'] = 0.7 * semantic_scores + 0.3 * df['dl_score'].values

    top_idx = df['final_score'].nlargest(top_n).index

    print(f"\n✅ Recommendations for '{user_input}':\n")

    for i in top_idx:
        p = df.loc[i]
        print(f"Product: {p['product_name']}")
        print(f"Category: {p['category']}")
        print(f"Rating: {p['overall_rating']} | Price: ₹{p['product_price']}")
        print("-" * 50)


# ===============================
# MAIN
# ===============================
if __name__ == "__main__":

    DATA_FOLDER = r"/content/electronics"

    df = load_datasets_from_folder(DATA_FOLDER)
    df = fill_and_encode_sentiment(df)

    # Clean price globally
    df['product_price'] = (
        df['product_price']
        .astype(str)
        .str.replace(r'[₹,\s]', '', regex=True)
    )
    df['product_price'] = pd.to_numeric(df['product_price'], errors='coerce')

    train_dl_sentiment_model(df)
    train_cnn_attention_recommender(df)
    prepare_recommendation_data(df)

    while True:
        name = input("\nEnter product name (or exit): ")
        if name.lower() == "exit":
            break
        recommend_products(name)
# Out:
# Loaded 500 records
#
# --- TRAINING DL SENTIMENT CLASSIFIER (BALANCED) ---
# Class weights: {0: np.float64(166.66666666666666), 1: np.float64(3.9682539682539684), 2: np.float64(0.36469730123997085)}
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.9155 - loss: 0.8190
# Epoch 2/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8958 - loss: 1.5851
# Epoch 3/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.9299 - loss: 1.4120
# Epoch 4/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8951 - loss: 0.9100
# Epoch 5/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9215 - loss: 1.1203
# Epoch 6/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9302 - loss: 0.9098
# Epoch 7/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9234 - loss: 0.9887
# Epoch 8/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9128 - loss: 1.2155
# Epoch 9/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9124 - loss: 1.3660
# Epoch 10/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9289 - loss: 0.9447
# Epoch 11/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9145 - loss: 0.9290
# Epoch 12/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9283 - loss: 0.8082
# Epoch 13/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9221 - loss: 1.0390
# Epoch 14/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9162 - loss: 1.6462
# Epoch 15/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9419 - loss: 0.8841
# Epoch 16/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9165 - loss: 1.3078
# Epoch 17/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9120 - loss: 0.6036
# Epoch 18/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9321 - loss: 1.5501
# Epoch 19/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9304 - loss: 1.0809
# Epoch 20/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9304 - loss: 0.9078
# Epoch 21/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9407 - loss: 0.8239
# Epoch 22/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9577 - loss: 0.6471
# Epoch 23/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9525 - loss: 0.5447
# Epoch 24/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9386 - loss: 0.8474
# Epoch 25/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9478 - loss: 1.3937
# Epoch 26/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.5523
# Epoch 27/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9829 - loss: 0.4814
# Epoch 28/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 1.0460
# Epoch 29/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 1.0051
# Epoch 30/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.9808
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 📊 DL Classification Report (Balanced):
#
#               precision    recall  f1-score   support
#
#     negative       1.00      1.00      1.00         1
#      neutral       1.00      1.00      1.00        42
#     positive       1.00      1.00      1.00       457
#
#     accuracy                           1.00       500
#    macro avg       1.00      1.00      1.00       500
# weighted avg       1.00      1.00      1.00       500
#
# ✅ DL sentiment model trained with class balancing
#
# --- TRAINING CNN + ATTENTION RECOMMENDER ---
# Epoch 1/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.4402
# Epoch 2/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.2346
# Epoch 3/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0464
# Epoch 4/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0077
# Epoch 5/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0027
# Epoch 6/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0023
# Epoch 7/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0021
# Epoch 8/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0015
# Epoch 9/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0017
# Epoch 10/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0013
# Epoch 11/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0011
# Epoch 12/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.7948e-04
# Epoch 13/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.9724e-04
# Epoch 14/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.0426e-04
# Epoch 15/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.2283e-04
# Epoch 16/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.4047e-05
# Epoch 17/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.5141e-05
# Epoch 18/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.2945e-04
# Epoch 19/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.1993e-05
# Epoch 20/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.0729e-05
# Epoch 21/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.7030e-04
# Epoch 22/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.4522e-05
# Epoch 23/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.9853e-05
# Epoch 24/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.4116e-05
# Epoch 25/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.4179e-05
# Epoch 26/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.5733e-04
# Epoch 27/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.2159e-05
# Epoch 28/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.4467e-05
# Epoch 29/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.2900e-05
# Epoch 30/30
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.5449e-05
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ✅ CNN + Attention recommender trained
#
# --- PREPARING RECOMMENDATION DATA ---
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# ✅ Recommendation data ready
#
# Enter product name (or exit): exit

# %% [markdown]
# # Footwear

# %%
# ===============================
# FOOTWEAR – AUTOENCODER VERSION
# ===============================

import pandas as pd
import numpy as np
import os
import glob
import joblib

from sklearn.preprocessing import MinMaxScaler, LabelEncoder
from sklearn.metrics import classification_report
from sklearn.metrics.pairwise import cosine_similarity

from sentence_transformers import SentenceTransformer

import tensorflow as tf
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.utils import to_categorical


# ===============================
# LOAD DATA
# ===============================
def load_datasets_from_folder(folder_path):
    all_files = glob.glob(os.path.join(folder_path, "*.csv"))
    if not all_files:
        raise Exception("No CSV files found!")

    df = pd.concat([pd.read_csv(f) for f in all_files], ignore_index=True)
    print(f"Loaded {len(df)} records")
    return df


# ===============================
# SENTIMENT PREPROCESSING
# ===============================
def fill_and_encode_sentiment(df):

    def rating_to_sentiment(r):
        if pd.isna(r):
            return 'neutral'
        elif r >= 4:
            return 'positive'
        elif r >= 3:
            return 'neutral'
        else:
            return 'negative'

    df['sentiment'] = df['sentiment'].fillna(
        df['overall_rating'].apply(rating_to_sentiment)
    )

    df['sentiment'] = df['sentiment'].str.lower().str.strip()

    sentiment_map = {'negative': 0, 'neutral': 1, 'positive': 2}
    df['sentiment_score'] = df['sentiment'].map(sentiment_map)

    return df


# ===============================
# DL SENTIMENT CLASSIFIER
# ===============================
def train_dl_sentiment_model(df):
    print("\n--- TRAINING DL SENTIMENT CLASSIFIER (BALANCED) ---")

    df = df.dropna(subset=['overall_rating', 'sentiment_score'])

    X = df[['overall_rating']].values
    y = df['sentiment_score'].values

    scaler = MinMaxScaler()
    X = scaler.fit_transform(X)

    y_cat = tf.keras.utils.to_categorical(y, num_classes=3)

    # 🔹 COMPUTE CLASS WEIGHTS
    class_counts = np.bincount(y)
    total = len(y)

    class_weights = {
        i: total / (3 * count) for i, count in enumerate(class_counts)
    }

    print("Class weights:", class_weights)

    # 🔹 DL MODEL
    model = tf.keras.Sequential([
        Dense(32, activation='relu', input_shape=(1,)),
        Dense(16, activation='relu'),
        Dense(3, activation='softmax')
    ])

    model.compile(
        optimizer='adam',
        loss='categorical_crossentropy',
        metrics=['accuracy']
    )

    model.fit(
        X,
        y_cat,
        epochs=30,
        batch_size=32,
        class_weight=class_weights,
        verbose=1
    )

    # 🔹 EVALUATION
    y_pred = model.predict(X)
    y_pred_labels = np.argmax(y_pred, axis=1)

    print("\n📊 DL Classification Report (Balanced):\n")
    print(classification_report(
        y,
        y_pred_labels,
        target_names=['negative', 'neutral', 'positive'],
        zero_division=0
    ))

    model.save("dl_sentiment_model.h5")
    joblib.dump(scaler, "dl_sentiment_scaler.pkl")

    print("✅ DL sentiment model trained with class balancing")


# ===============================
# AUTOENCODER RECOMMENDER (DL)
# ===============================
def train_autoencoder_recommender(df):
    print("\n--- TRAINING AUTOENCODER RECOMMENDER ---")

    df = df.dropna(subset=['overall_rating', 'sentiment_score', 'product_price'])

    X = df[['overall_rating', 'sentiment_score', 'product_price']].values
    X = MinMaxScaler().fit_transform(X)

    input_layer = Input(shape=(3,))
    encoded = Dense(16, activation='relu')(input_layer)
    encoded = Dense(8, activation='relu')(encoded)
    decoded = Dense(3, activation='linear')(encoded)

    autoencoder = Model(input_layer, decoded)
    autoencoder.compile(
        optimizer='adam',
        loss=tf.keras.losses.MeanSquaredError()
    )

    autoencoder.fit(X, X, epochs=30, batch_size=32, verbose=1)
    autoencoder.save("ae_recommender.h5")

    print("✅ Autoencoder trained")


# ===============================
# PREPARE RECOMMENDATION DATA
# ===============================
def prepare_recommendation_data(df):
    print("\n--- PREPARING RECOMMENDATION DATA ---")

    df = df.dropna(subset=[
        'product_name', 'category',
        'product_price', 'overall_rating', 'sentiment_score'
    ])

    features = df[['overall_rating', 'sentiment_score', 'product_price']]
    scaler = MinMaxScaler()
    features_scaled = scaler.fit_transform(features)

    similarity_matrix = cosine_similarity(features_scaled)

    joblib.dump(df, "products_data.pkl")
    joblib.dump(similarity_matrix, "similarity_matrix.pkl")

    model_embed = SentenceTransformer('all-MiniLM-L6-v2')
    df['text'] = df['product_name'] + " " + df['category']
    embeddings = model_embed.encode(df['text'].tolist(), convert_to_tensor=True)

    joblib.dump(embeddings.cpu().numpy(), "product_embeddings.pkl")
    joblib.dump(model_embed, "embedding_model.pkl")

    print("✅ Recommendation data ready")


# ===============================
# RECOMMEND PRODUCTS
# ===============================
def recommend_products(user_input, top_n=5):

    df = joblib.load("products_data.pkl")
    embeddings = joblib.load("product_embeddings.pkl")
    model_embed = joblib.load("embedding_model.pkl")

    query_emb = model_embed.encode(user_input, convert_to_tensor=True)
    scores = cosine_similarity(query_emb.reshape(1, -1), embeddings)[0]

    top_idx = np.argsort(scores)[::-1][:top_n]

    print(f"\n✅ Recommendations for '{user_input}':\n")

    for i in top_idx:
        p = df.iloc[i]
        print(f"Product: {p['product_name']}")
        print(f"Category: {p['category']}")
        print(f"Rating: {p['overall_rating']} | Price: ₹{p['product_price']}")
        print("-" * 50)


# ===============================
# MAIN
# ===============================
if __name__ == "__main__":

    DATA_FOLDER = r"/content/footwear"

    df = load_datasets_from_folder(DATA_FOLDER)
    df = fill_and_encode_sentiment(df)

    # Clean price globally
    df['product_price'] = (
        df['product_price']
        .astype(str)
        .str.replace(r'[₹,\s]', '', regex=True)
    )
    df['product_price'] = pd.to_numeric(df['product_price'], errors='coerce')

    train_dl_sentiment_model(df)
    train_autoencoder_recommender(df)
    prepare_recommendation_data(df)

    while True:
        name = input("\nEnter product name (or exit): ")
        if name.lower() == "exit":
            break
        recommend_products(name)
# Out:
# Loaded 271 records
#
# --- TRAINING DL SENTIMENT CLASSIFIER (BALANCED) ---
# Class weights: {0: np.float64(29.666666666666668), 1: np.float64(0.9175257731958762), 2: np.float64(0.5329341317365269)}
# Epoch 1/30
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.0000e+00 - loss: 1.0390
# Epoch 2/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5668 - loss: 1.1239
# Epoch 3/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6394 - loss: 1.1798
# Epoch 4/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6326 - loss: 1.2270
# Epoch 5/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5780 - loss: 1.2574
# Epoch 6/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6423 - loss: 1.0204
# Epoch 7/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6361 - loss: 1.0794
# Epoch 8/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6438 - loss: 1.0863
# Epoch 9/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5817 - loss: 1.4896
# Epoch 10/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6547 - loss: 0.9228
# Epoch 11/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6128 - loss: 1.1254
# Epoch 12/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6500 - loss: 0.9611
# Epoch 13/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6484 - loss: 0.8611
# Epoch 14/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6371 - loss: 1.1648
# Epoch 15/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6383 - loss: 0.7738
# Epoch 16/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6295 - loss: 1.2006
# Epoch 17/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6184 - loss: 1.1364
# Epoch 18/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6484 - loss: 0.9083
# Epoch 19/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6501 - loss: 0.7376
# Epoch 20/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6563 - loss: 0.9510
# Epoch 21/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6432 - loss: 0.8993
# Epoch 22/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6368 - loss: 0.8467
# Epoch 23/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6195 - loss: 0.8357
# Epoch 24/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6353 - loss: 0.8258
# Epoch 25/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6214 - loss: 0.9782
# Epoch 26/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6578 - loss: 1.0883
# Epoch 27/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6068 - loss: 0.9424
# Epoch 28/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6042 - loss: 1.0108
# Epoch 29/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6092 - loss: 0.9425
# Epoch 30/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6244 - loss: 0.8905
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 📊 DL Classification Report (Balanced):
#
#               precision    recall  f1-score   support
#
#     negative       1.00      1.00      1.00         3
#      neutral       0.00      0.00      0.00        97
#     positive       0.63      1.00      0.77       167
#
#     accuracy                           0.64       267
#    macro avg       0.54      0.67      0.59       267
# weighted avg       0.41      0.64      0.50       267
#
# ✅ DL sentiment model trained with class balancing
#
# --- TRAINING AUTOENCODER RECOMMENDER ---
# Epoch 1/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.1001
# Epoch 2/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0552
# Epoch 3/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0259
# Epoch 4/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0081
# Epoch 5/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0047
# Epoch 6/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0068
# Epoch 7/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0050
# Epoch 8/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0039
# Epoch 9/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0044
# Epoch 10/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0036
# Epoch 11/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0045
# Epoch 12/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0033
# Epoch 13/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0052
# Epoch 14/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0051
# Epoch 15/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0030
# Epoch 16/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0028
# Epoch 17/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0031
# Epoch 18/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0028
# Epoch 19/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0045
# Epoch 20/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0027
# Epoch 21/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0035
# Epoch 22/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0027
# Epoch 23/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0023
# Epoch 24/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0027
# Epoch 25/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0020
# Epoch 26/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0017
# Epoch 27/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0020
# Epoch 28/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0022
# Epoch 29/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0025
# Epoch 30/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0023
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ✅ Autoencoder trained
#
# --- PREPARING RECOMMENDATION DATA ---
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# /tmp/ipython-input-3865279053.py:178: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['text'] = df['product_name'] + " " + df['category']
# ✅ Recommendation data ready
#
# Enter product name (or exit): exit

# %%
# ===============================
# FOOTWEAR – LSTM VERSION
# ===============================

import pandas as pd
import numpy as np
import os
import glob
import joblib

from sklearn.preprocessing import MinMaxScaler, LabelEncoder
from sklearn.metrics import classification_report
from sklearn.metrics.pairwise import cosine_similarity

from sentence_transformers import SentenceTransformer

import tensorflow as tf
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import LSTM, Attention, Reshape, Flatten


# ===============================
# LOAD DATA
# ===============================
def load_datasets_from_folder(folder_path):
    all_files = glob.glob(os.path.join(folder_path, "*.csv"))
    if not all_files:
        raise Exception("No CSV files found!")

    df = pd.concat([pd.read_csv(f) for f in all_files], ignore_index=True)
    print(f"Loaded {len(df)} records")
    return df


# ===============================
# SENTIMENT PREPROCESSING
# ===============================
def fill_and_encode_sentiment(df):

    def rating_to_sentiment(r):
        if pd.isna(r):
            return 'neutral'
        elif r >= 4:
            return 'positive'
        elif r >= 3:
            return 'neutral'
        else:
            return 'negative'

    df['sentiment'] = df['sentiment'].fillna(
        df['overall_rating'].apply(rating_to_sentiment)
    )

    df['sentiment'] = df['sentiment'].str.lower().str.strip()

    sentiment_map = {'negative': 0, 'neutral': 1, 'positive': 2}
    df['sentiment_score'] = df['sentiment'].map(sentiment_map)

    return df


# ===============================
# DL SENTIMENT CLASSIFIER
# ===============================
def train_dl_sentiment_model(df):
    print("\n--- TRAINING DL SENTIMENT CLASSIFIER (BALANCED) ---")

    df = df.dropna(subset=['overall_rating', 'sentiment_score'])

    X = df[['overall_rating']].values
    y = df['sentiment_score'].values

    scaler = MinMaxScaler()
    X = scaler.fit_transform(X)

    y_cat = tf.keras.utils.to_categorical(y, num_classes=3)

    # 🔹 COMPUTE CLASS WEIGHTS
    class_counts = np.bincount(y)
    total = len(y)

    class_weights = {
        i: total / (3 * count) for i, count in enumerate(class_counts)
    }

    print("Class weights:", class_weights)

    # 🔹 DL MODEL
    model = tf.keras.Sequential([
        Dense(32, activation='relu', input_shape=(1,)),
        Dense(16, activation='relu'),
        Dense(3, activation='softmax')
    ])

    model.compile(
        optimizer='adam',
        loss='categorical_crossentropy',
        metrics=['accuracy']
    )

    model.fit(
        X,
        y_cat,
        epochs=30,
        batch_size=32,
        class_weight=class_weights,
        verbose=1
    )

    # 🔹 EVALUATION
    y_pred = model.predict(X)
    y_pred_labels = np.argmax(y_pred, axis=1)

    print("\n📊 DL Classification Report (Balanced):\n")
    print(classification_report(
        y,
        y_pred_labels,
        target_names=['negative', 'neutral', 'positive'],
        zero_division=0
    ))

    model.save("dl_sentiment_model.h5")
    joblib.dump(scaler, "dl_sentiment_scaler.pkl")

    print("✅ DL sentiment model trained with class balancing")


# ===============================
# LSTM + ATTENTION RECOMMENDER (DL)
# ===============================
def train_lstm_attention_recommender(df):
    print("\n--- TRAINING LSTM + ATTENTION RECOMMENDER ---")

    df = df.dropna(subset=['overall_rating', 'sentiment_score', 'product_price'])

    # 🔹 Feature matrix
    X = df[['overall_rating', 'sentiment_score', 'product_price']].values
    X = MinMaxScaler().fit_transform(X)

    # 🔹 Convert to sequence format (timesteps = features)
    # Shape: (samples, timesteps, features_per_step)
    X_seq = X.reshape((X.shape[0], X.shape[1], 1))

    # 🔹 INPUT
    input_layer = Input(shape=(X_seq.shape[1], 1))

    # 🔹 LSTM
    lstm_out = LSTM(64, return_sequences=True)(input_layer)

    # 🔹 ATTENTION
    attention_out = Attention()([lstm_out, lstm_out])

    # 🔹 FLATTEN
    flat = Flatten()(attention_out)

    # 🔹 OUTPUT (reconstruct input features)
    output_layer = Dense(X.shape[1], activation='linear')(flat)

    # 🔹 MODEL
    model = Model(inputs=input_layer, outputs=output_layer)

    model.compile(
        optimizer='adam',
        loss=tf.keras.losses.MeanSquaredError()
    )

    model.fit(
        X_seq,
        X,
        epochs=30,
        batch_size=32,
        verbose=1
    )

    model.save("lstm_attention_recommender.h5")

    print("✅ LSTM + Attention recommender trained")

# ===============================
# PREPARE RECOMMENDATION DATA
# ===============================
def prepare_recommendation_data(df):
    print("\n--- PREPARING RECOMMENDATION DATA ---")

    df = df.dropna(subset=[
        'product_name', 'category',
        'product_price', 'overall_rating', 'sentiment_score'
    ])

    features = df[['overall_rating', 'sentiment_score', 'product_price']]
    scaler = MinMaxScaler()
    features_scaled = scaler.fit_transform(features)

    similarity_matrix = cosine_similarity(features_scaled)

    joblib.dump(df, "products_data.pkl")
    joblib.dump(similarity_matrix, "similarity_matrix.pkl")

    model_embed = SentenceTransformer('all-MiniLM-L6-v2')
    df['text'] = df['product_name'] + " " + df['category']
    embeddings = model_embed.encode(df['text'].tolist(), convert_to_tensor=True)

    joblib.dump(embeddings.cpu().numpy(), "product_embeddings.pkl")
    joblib.dump(model_embed, "embedding_model.pkl")

    print("✅ Recommendation data ready")


# ===============================
# RECOMMEND PRODUCTS
# ===============================
def recommend_products(user_input, top_n=5):

    df = joblib.load("products_data.pkl")
    embeddings = joblib.load("product_embeddings.pkl")
    model_embed = joblib.load("embedding_model.pkl")

    query_emb = model_embed.encode(user_input, convert_to_tensor=True)
    scores = cosine_similarity(query_emb.reshape(1, -1), embeddings)[0]

    top_idx = np.argsort(scores)[::-1][:top_n]

    print(f"\n✅ Recommendations for '{user_input}':\n")

    for i in top_idx:
        p = df.iloc[i]
        print(f"Product: {p['product_name']}")
        print(f"Category: {p['category']}")
        print(f"Rating: {p['overall_rating']} | Price: ₹{p['product_price']}")
        print("-" * 50)


# ===============================
# MAIN
# ===============================
if __name__ == "__main__":

    DATA_FOLDER = r"/content/footwear"

    df = load_datasets_from_folder(DATA_FOLDER)
    df = fill_and_encode_sentiment(df)

    # Clean price globally
    df['product_price'] = (
        df['product_price']
        .astype(str)
        .str.replace(r'[₹,\s]', '', regex=True)
    )
    df['product_price'] = pd.to_numeric(df['product_price'], errors='coerce')

    train_dl_sentiment_model(df)
    train_lstm_attention_recommender(df)
    prepare_recommendation_data(df)

    while True:
        name = input("\nEnter product name (or exit): ")
        if name.lower() == "exit":
            break
        recommend_products(name)
# Out:
# Loaded 271 records
#
# --- TRAINING DL SENTIMENT CLASSIFIER (BALANCED) ---
# Class weights: {0: np.float64(29.666666666666668), 1: np.float64(0.9175257731958762), 2: np.float64(0.5329341317365269)}
# Epoch 1/30
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.0061 - loss: 1.2230
# Epoch 2/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0000e+00 - loss: 0.9476
# Epoch 3/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0510 - loss: 1.0644
# Epoch 4/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6988 - loss: 1.1381
# Epoch 5/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6079 - loss: 1.0162
# Epoch 6/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6331 - loss: 1.1887
# Epoch 7/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6237 - loss: 1.1611
# Epoch 8/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6375 - loss: 1.1759
# Epoch 9/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.6259 - loss: 1.2253
# Epoch 10/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.6203 - loss: 0.8831
# Epoch 11/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.6549 - loss: 1.1172
# Epoch 12/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.6078 - loss: 1.1234
# Epoch 13/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.6197 - loss: 1.0704
# Epoch 14/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6558 - loss: 0.7921
# Epoch 15/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.6801 - loss: 1.0025
# Epoch 16/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6412 - loss: 0.7989
# Epoch 17/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6630 - loss: 0.7457
# Epoch 18/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6253 - loss: 0.9830
# Epoch 19/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6144 - loss: 0.9243
# Epoch 20/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6352 - loss: 1.0685
# Epoch 21/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6289 - loss: 0.9455
# Epoch 22/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6368 - loss: 0.9842
# Epoch 23/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6284 - loss: 0.7840
# Epoch 24/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6134 - loss: 1.1876
# Epoch 25/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5978 - loss: 0.8709
# Epoch 26/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6177 - loss: 0.8877
# Epoch 27/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5921 - loss: 0.9860
# Epoch 28/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6490 - loss: 0.7775
# Epoch 29/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6476 - loss: 0.8207
# Epoch 30/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6447 - loss: 0.8736
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 📊 DL Classification Report (Balanced):
#
#               precision    recall  f1-score   support
#
#     negative       1.00      1.00      1.00         3
#      neutral       1.00      0.15      0.27        97
#     positive       0.67      1.00      0.80       167
#
#     accuracy                           0.69       267
#    macro avg       0.89      0.72      0.69       267
# weighted avg       0.79      0.69      0.61       267
#
# ✅ DL sentiment model trained with class balancing
#
# --- TRAINING LSTM + ATTENTION RECOMMENDER ---
# Epoch 1/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 0.3520
# Epoch 2/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2557
# Epoch 3/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1685
# Epoch 4/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0801
# Epoch 5/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0185
# Epoch 6/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0159
# Epoch 7/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0123
# Epoch 8/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0094
# Epoch 9/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0096
# Epoch 10/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0070
# Epoch 11/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0076
# Epoch 12/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0072
# Epoch 13/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0067
# Epoch 14/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0068
# Epoch 15/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0065
# Epoch 16/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0064
# Epoch 17/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0057
# Epoch 18/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0075
# Epoch 19/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0051
# Epoch 20/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0068
# Epoch 21/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0058
# Epoch 22/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0070
# Epoch 23/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0049
# Epoch 24/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0057
# Epoch 25/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0045
# Epoch 26/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0042
# Epoch 27/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0050
# Epoch 28/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0046
# Epoch 29/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0043
# Epoch 30/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0044
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ✅ LSTM + Attention recommender trained
#
# --- PREPARING RECOMMENDATION DATA ---
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# /tmp/ipython-input-4015629570.py:202: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['text'] = df['product_name'] + " " + df['category']
# ✅ Recommendation data ready
#
# Enter product name (or exit): exit

# %%
# ===============================
# FOOTWEAR - CNN VERSION
# ===============================

import pandas as pd
import numpy as np
import os
import glob
import joblib

from sklearn.preprocessing import MinMaxScaler, LabelEncoder
from sklearn.metrics import classification_report
from sklearn.metrics.pairwise import cosine_similarity

from sentence_transformers import SentenceTransformer

import tensorflow as tf
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Conv1D, GlobalAveragePooling1D
from tensorflow.keras.layers import Attention, Reshape


# ===============================
# LOAD DATA
# ===============================
def load_datasets_from_folder(folder_path):
    all_files = glob.glob(os.path.join(folder_path, "*.csv"))
    if not all_files:
        raise Exception("No CSV files found!")

    df = pd.concat([pd.read_csv(f) for f in all_files], ignore_index=True)
    print(f"Loaded {len(df)} records")
    return df


# ===============================
# SENTIMENT PREPROCESSING
# ===============================
def fill_and_encode_sentiment(df):

    def rating_to_sentiment(r):
        if pd.isna(r):
            return 'neutral'
        elif r >= 4:
            return 'positive'
        elif r >= 3:
            return 'neutral'
        else:
            return 'negative'

    df['sentiment'] = df['sentiment'].fillna(
        df['overall_rating'].apply(rating_to_sentiment)
    )

    df['sentiment'] = df['sentiment'].str.lower().str.strip()

    sentiment_map = {'negative': 0, 'neutral': 1, 'positive': 2}
    df['sentiment_score'] = df['sentiment'].map(sentiment_map)

    return df


# ===============================
# DL SENTIMENT CLASSIFIER
# ===============================
def train_dl_sentiment_model(df):
    print("\n--- TRAINING DL SENTIMENT CLASSIFIER (BALANCED) ---")

    df = df.dropna(subset=['overall_rating', 'sentiment_score'])

    df['neutral_distance'] = np.abs(df['overall_rating'] - 3)

    X = df[['overall_rating', 'neutral_distance']].values

    y = df['sentiment_score'].values

    scaler = MinMaxScaler()
    X = scaler.fit_transform(X)

    y_cat = tf.keras.utils.to_categorical(y, num_classes=3)

    # 🔹 COMPUTE CLASS WEIGHTS
    class_counts = np.bincount(y)
    total = len(y)

    class_weights = {
        i: total / (3 * count) for i, count in enumerate(class_counts)
    }

    print("Class weights:", class_weights)

    # 🔹 DL MODEL
    model = tf.keras.Sequential([
        Dense(32, activation='relu', input_shape=(2,)),
        Dense(16, activation='relu'),
        Dense(3, activation='softmax')
    ])

    model.compile(
        optimizer='adam',
        loss=tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.1),
        metrics=['accuracy']
    )

    model.fit(
        X,
        y_cat,
        epochs=30,
        batch_size=32,
        class_weight=class_weights,
        verbose=1
    )

    # 🔹 EVALUATION
    y_pred = model.predict(X)
    y_pred_labels = np.argmax(y_pred, axis=1)

    print("\n📊 DL Classification Report (Balanced):\n")
    print(classification_report(
        y,
        y_pred_labels,
        target_names=['negative', 'neutral', 'positive'],
        zero_division=0
    ))

    model.save("dl_sentiment_model.h5")
    joblib.dump(scaler, "dl_sentiment_scaler.pkl")

    print("✅ DL sentiment model trained with class balancing")


# ===============================
# CNN + ATTENTION RECOMMENDER (DL)
# ===============================
def train_cnn_attention_recommender(df):
    print("\n--- TRAINING CNN + ATTENTION RECOMMENDER ---")

    df = df.dropna(subset=['overall_rating', 'sentiment_score', 'product_price'])

    # 🔹 Feature matrix
    df['neutral_distance'] = np.abs(df['overall_rating'] - 3)

    X = df[['overall_rating', 'neutral_distance']].values

    X = MinMaxScaler().fit_transform(X)

    # 🔹 Reshape for CNN
    # Shape: (samples, timesteps, channels)
    X_seq = X.reshape((X.shape[0], X.shape[1], 1))

    # 🔹 INPUT
    input_layer = Input(shape=(X_seq.shape[1], 1))

    # 🔹 CNN layers
    conv1 = Conv1D(filters=64, kernel_size=2, activation='relu', padding='same')(input_layer)
    conv2 = Conv1D(filters=32, kernel_size=2, activation='relu', padding='same')(conv1)

    # 🔹 ATTENTION
    attention_out = Attention()([conv2, conv2])

    # 🔹 POOLING
    pooled = GlobalAveragePooling1D()(attention_out)

    # 🔹 OUTPUT (reconstruction)
    output_layer = Dense(X.shape[1], activation='linear')(pooled)

    # 🔹 MODEL
    model = Model(inputs=input_layer, outputs=output_layer)

    model.compile(
        optimizer='adam',
        loss=tf.keras.losses.MeanSquaredError()
    )

    model.fit(
        X_seq,
        X,
        epochs=30,
        batch_size=32,
        verbose=1
    )

    model.save("cnn_attention_recommender.h5")

    print("✅ CNN + Attention recommender trained")

# ===============================
# PREPARE RECOMMENDATION DATA
# ===============================
def prepare_recommendation_data(df):
    print("\n--- PREPARING RECOMMENDATION DATA ---")

    df = df.dropna(subset=[
        'product_name', 'category',
        'product_price', 'overall_rating', 'sentiment_score'
    ])

    features = df[['overall_rating', 'sentiment_score', 'product_price']]
    scaler = MinMaxScaler()
    features_scaled = scaler.fit_transform(features)

    similarity_matrix = cosine_similarity(features_scaled)

    joblib.dump(df, "products_data.pkl")
    joblib.dump(similarity_matrix, "similarity_matrix.pkl")

    model_embed = SentenceTransformer('all-MiniLM-L6-v2')
    df['text'] = df['product_name'] + " " + df['category']
    embeddings = model_embed.encode(df['text'].tolist(), convert_to_tensor=True)

    joblib.dump(embeddings.cpu().numpy(), "product_embeddings.pkl")
    joblib.dump(model_embed, "embedding_model.pkl")

    print("✅ Recommendation data ready")


# ===============================
# RECOMMEND PRODUCTS
# ===============================
def recommend_products(user_input, top_n=5):

    df = joblib.load("products_data.pkl")
    embeddings = joblib.load("product_embeddings.pkl")
    model_embed = joblib.load("embedding_model.pkl")

    # 🔹 Load CNN model
    cnn_model = tf.keras.models.load_model("cnn_attention_recommender.h5")

    # 🔹 Prepare features
    df['neutral_distance'] = np.abs(df['overall_rating'] - 3)
    X = df[['overall_rating', 'neutral_distance']].values
    X = MinMaxScaler().fit_transform(X)
    X_seq = X.reshape((X.shape[0], X.shape[1], 1))

    # 🔹 CNN reconstruction error
    recon = cnn_model.predict(X_seq, verbose=0)
    recon_error = np.mean(np.square(X - recon), axis=1)
    df['dl_score'] = -recon_error

    # 🔹 Semantic similarity
    query_emb = model_embed.encode(user_input, convert_to_tensor=True)
    semantic_scores = cosine_similarity(
        query_emb.reshape(1, -1), embeddings
    )[0]

    # 🔹 Final hybrid score
    df['final_score'] = 0.7 * semantic_scores + 0.3 * df['dl_score'].values

    top_idx = df['final_score'].nlargest(top_n).index

    print(f"\n✅ Recommendations for '{user_input}':\n")

    for i in top_idx:
        p = df.loc[i]
        print(f"Product: {p['product_name']}")
        print(f"Category: {p['category']}")
        print(f"Rating: {p['overall_rating']} | Price: ₹{p['product_price']}")
        print("-" * 50)


# ===============================
# MAIN
# ===============================
if __name__ == "__main__":

    DATA_FOLDER = r"/content/footwear"

    df = load_datasets_from_folder(DATA_FOLDER)
    df = fill_and_encode_sentiment(df)

    # Clean price globally
    df['product_price'] = (
        df['product_price']
        .astype(str)
        .str.replace(r'[₹,\s]', '', regex=True)
    )
    df['product_price'] = pd.to_numeric(df['product_price'], errors='coerce')

    train_dl_sentiment_model(df)
    train_cnn_attention_recommender(df)
    prepare_recommendation_data(df)

    while True:
        name = input("\nEnter product name (or exit): ")
        if name.lower() == "exit":
            break
        recommend_products(name)
# Out:
# Loaded 271 records
#
# --- TRAINING DL SENTIMENT CLASSIFIER (BALANCED) ---
# Class weights: {0: np.float64(29.666666666666668), 1: np.float64(0.9175257731958762), 2: np.float64(0.5329341317365269)}
# Epoch 1/30
# /tmp/ipython-input-3302426368.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['neutral_distance'] = np.abs(df['overall_rating'] - 3)
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.2485 - loss: 1.2653
# Epoch 2/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6733 - loss: 1.0656
# Epoch 3/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6525 - loss: 1.2623
# Epoch 4/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6686 - loss: 1.1339
# Epoch 5/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6662 - loss: 0.9357
# Epoch 6/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6435 - loss: 1.0120
# Epoch 7/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6799 - loss: 0.8998
# Epoch 8/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6877 - loss: 0.9215
# Epoch 9/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6619 - loss: 0.9957
# Epoch 10/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6951 - loss: 0.8384
# Epoch 11/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6976 - loss: 0.7368
# Epoch 12/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6708 - loss: 0.9774
# Epoch 13/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6892 - loss: 0.9435
# Epoch 14/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6657 - loss: 0.8412
# Epoch 15/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6809 - loss: 0.8818
# Epoch 16/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7178 - loss: 0.8337
# Epoch 17/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7011 - loss: 0.7638
# Epoch 18/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7417 - loss: 0.7149
# Epoch 19/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8103 - loss: 0.7421
# Epoch 20/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8156 - loss: 0.7061
# Epoch 21/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8586 - loss: 0.7171
# Epoch 22/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8743 - loss: 0.6400
# Epoch 23/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8214 - loss: 0.5672
# Epoch 24/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8730 - loss: 0.6071
# Epoch 25/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8739 - loss: 0.6168
# Epoch 26/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8708 - loss: 0.6105
# Epoch 27/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8650 - loss: 0.5695
# Epoch 28/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8858 - loss: 0.5341
# Epoch 29/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8897 - loss: 0.5247
# Epoch 30/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8823 - loss: 0.5635
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 📊 DL Classification Report (Balanced):
#
#               precision    recall  f1-score   support
#
#     negative       1.00      1.00      1.00         3
#      neutral       1.00      0.71      0.83        97
#     positive       0.86      1.00      0.92       167
#
#     accuracy                           0.90       267
#    macro avg       0.95      0.90      0.92       267
# weighted avg       0.91      0.90      0.89       267
#
# ✅ DL sentiment model trained with class balancing
#
# --- TRAINING CNN + ATTENTION RECOMMENDER ---
# Epoch 1/30
# /tmp/ipython-input-3302426368.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['neutral_distance'] = np.abs(df['overall_rating'] - 3)
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.2959
# Epoch 2/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.2048
# Epoch 3/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1104
# Epoch 4/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0320
# Epoch 5/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0046
# Epoch 6/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0080
# Epoch 7/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0039
# Epoch 8/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0039
# Epoch 9/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0027
# Epoch 10/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0027
# Epoch 11/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0015
# Epoch 12/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0018
# Epoch 13/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.5456e-04
# Epoch 14/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0012
# Epoch 15/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.5657e-04
# Epoch 16/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.5659e-04
# Epoch 17/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.7448e-04
# Epoch 18/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.1843e-04
# Epoch 19/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.2850e-04
# Epoch 20/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.3723e-04
# Epoch 21/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.0617e-04
# Epoch 22/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.6035e-04
# Epoch 23/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.7373e-04
# Epoch 24/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.9941e-04
# Epoch 25/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.1277e-04
# Epoch 26/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.1116e-05
# Epoch 27/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.4599e-05
# Epoch 28/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.0253e-04
# Epoch 29/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.0237e-05
# Epoch 30/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.5201e-05
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ✅ CNN + Attention recommender trained
#
# --- PREPARING RECOMMENDATION DATA ---
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# /tmp/ipython-input-3302426368.py:210: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['text'] = df['product_name'] + " " + df['category']
# ✅ Recommendation data ready
#
# Enter product name (or exit): exit

# %% [markdown]
# # WEARABLES

# %%
# ===============================
# WEARABLES – AUTOENCODER VERSION
# ===============================

import pandas as pd
import numpy as np
import os
import glob
import joblib

from sklearn.preprocessing import MinMaxScaler, LabelEncoder
from sklearn.metrics import classification_report
from sklearn.metrics.pairwise import cosine_similarity

from sentence_transformers import SentenceTransformer

import tensorflow as tf
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.utils import to_categorical


# ===============================
# LOAD DATA
# ===============================
def load_datasets_from_folder(folder_path):
    all_files = glob.glob(os.path.join(folder_path, "*.csv"))
    if not all_files:
        raise Exception("No CSV files found!")

    df = pd.concat([pd.read_csv(f) for f in all_files], ignore_index=True)
    print(f"Loaded {len(df)} records")
    return df


# ===============================
# SENTIMENT PREPROCESSING
# ===============================
def fill_and_encode_sentiment(df):

    def rating_to_sentiment(r):
        if pd.isna(r):
            return 'neutral'
        elif r >= 4:
            return 'positive'
        elif r >= 3:
            return 'neutral'
        else:
            return 'negative'

    df['sentiment'] = df['sentiment'].fillna(
        df['overall_rating'].apply(rating_to_sentiment)
    )

    df['sentiment'] = df['sentiment'].str.lower().str.strip()

    sentiment_map = {'negative': 0, 'neutral': 1, 'positive': 2}
    df['sentiment_score'] = df['sentiment'].map(sentiment_map)

    return df


# ===============================
# DL SENTIMENT CLASSIFIER
# ===============================
def train_dl_sentiment_model(df):
    print("\n--- TRAINING DL SENTIMENT CLASSIFIER (BALANCED) ---")

    df = df.dropna(subset=['overall_rating', 'sentiment_score'])

    X = df[['overall_rating']].values
    y = df['sentiment_score'].values

    scaler = MinMaxScaler()
    X = scaler.fit_transform(X)

    y_cat = tf.keras.utils.to_categorical(y, num_classes=3)

    # 🔹 COMPUTE CLASS WEIGHTS
    class_counts = np.bincount(y)
    total = len(y)

    class_weights = {
        i: total / (3 * count) for i, count in enumerate(class_counts)
    }

    print("Class weights:", class_weights)

    # 🔹 DL MODEL
    model = tf.keras.Sequential([
        Dense(32, activation='relu', input_shape=(1,)),
        Dense(16, activation='relu'),
        Dense(3, activation='softmax')
    ])

    model.compile(
        optimizer='adam',
        loss='categorical_crossentropy',
        metrics=['accuracy']
    )

    model.fit(
        X,
        y_cat,
        epochs=30,
        batch_size=32,
        class_weight=class_weights,
        verbose=1
    )

    # 🔹 EVALUATION
    y_pred = model.predict(X)
    y_pred_labels = np.argmax(y_pred, axis=1)

    print("\n📊 DL Classification Report (Balanced):\n")
    print(classification_report(
        y,
        y_pred_labels,
        target_names=['negative', 'neutral', 'positive'],
        zero_division=0
    ))

    model.save("dl_sentiment_model.h5")
    joblib.dump(scaler, "dl_sentiment_scaler.pkl")

    print("✅ DL sentiment model trained with class balancing")


# ===============================
# AUTOENCODER RECOMMENDER (DL)
# ===============================
def train_autoencoder_recommender(df):
    print("\n--- TRAINING AUTOENCODER RECOMMENDER ---")

    df = df.dropna(subset=['overall_rating', 'sentiment_score', 'product_price'])

    X = df[['overall_rating', 'sentiment_score', 'product_price']].values
    X = MinMaxScaler().fit_transform(X)

    input_layer = Input(shape=(3,))
    encoded = Dense(16, activation='relu')(input_layer)
    encoded = Dense(8, activation='relu')(encoded)
    decoded = Dense(3, activation='linear')(encoded)

    autoencoder = Model(input_layer, decoded)
    autoencoder.compile(
        optimizer='adam',
        loss=tf.keras.losses.MeanSquaredError()
    )

    autoencoder.fit(X, X, epochs=30, batch_size=32, verbose=1)
    autoencoder.save("ae_recommender.h5")

    print("✅ Autoencoder trained")


# ===============================
# PREPARE RECOMMENDATION DATA
# ===============================
def prepare_recommendation_data(df):
    print("\n--- PREPARING RECOMMENDATION DATA ---")

    df = df.dropna(subset=[
        'product_name', 'category',
        'product_price', 'overall_rating', 'sentiment_score'
    ])

    features = df[['overall_rating', 'sentiment_score', 'product_price']]
    scaler = MinMaxScaler()
    features_scaled = scaler.fit_transform(features)

    similarity_matrix = cosine_similarity(features_scaled)

    joblib.dump(df, "products_data.pkl")
    joblib.dump(similarity_matrix, "similarity_matrix.pkl")

    model_embed = SentenceTransformer('all-MiniLM-L6-v2')
    df['text'] = df['product_name'] + " " + df['category']
    embeddings = model_embed.encode(df['text'].tolist(), convert_to_tensor=True)

    joblib.dump(embeddings.cpu().numpy(), "product_embeddings.pkl")
    joblib.dump(model_embed, "embedding_model.pkl")

    print("✅ Recommendation data ready")


# ===============================
# RECOMMEND PRODUCTS
# ===============================
def recommend_products(user_input, top_n=5):

    df = joblib.load("products_data.pkl")
    embeddings = joblib.load("product_embeddings.pkl")
    model_embed = joblib.load("embedding_model.pkl")

    query_emb = model_embed.encode(user_input, convert_to_tensor=True)
    scores = cosine_similarity(query_emb.reshape(1, -1), embeddings)[0]

    top_idx = np.argsort(scores)[::-1][:top_n]

    print(f"\n✅ Recommendations for '{user_input}':\n")

    for i in top_idx:
        p = df.iloc[i]
        print(f"Product: {p['product_name']}")
        print(f"Category: {p['category']}")
        print(f"Rating: {p['overall_rating']} | Price: ₹{p['product_price']}")
        print("-" * 50)


# ===============================
# MAIN
# ===============================
if __name__ == "__main__":

    DATA_FOLDER = r"/content/Wearables"

    df = load_datasets_from_folder(DATA_FOLDER)
    df = fill_and_encode_sentiment(df)

    # Clean price globally
    df['product_price'] = (
        df['product_price']
        .astype(str)
        .str.replace(r'[₹,\s]', '', regex=True)
    )
    df['product_price'] = pd.to_numeric(df['product_price'], errors='coerce')

    train_dl_sentiment_model(df)
    train_autoencoder_recommender(df)
    prepare_recommendation_data(df)

    while True:
        name = input("\nEnter product name (or exit): ")
        if name.lower() == "exit":
            break
        recommend_products(name)
# Out:
# Loaded 150 records
#
# --- TRAINING DL SENTIMENT CLASSIFIER (BALANCED) ---
# Class weights: {0: np.float64(7.611111111111111), 1: np.float64(0.9513888888888888), 2: np.float64(0.5502008032128514)}
# Epoch 1/30
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.6099 - loss: 0.9503
# Epoch 2/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6112 - loss: 1.0689
# Epoch 3/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6158 - loss: 0.9407
# Epoch 4/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6059 - loss: 1.0880
# Epoch 5/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5815 - loss: 1.1362
# Epoch 6/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5707 - loss: 1.0293
# Epoch 7/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5920 - loss: 0.9153
# Epoch 8/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6237 - loss: 1.0680
# Epoch 9/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5989 - loss: 0.9929
# Epoch 10/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5850 - loss: 0.8651
# Epoch 11/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6106 - loss: 1.1498
# Epoch 12/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6436 - loss: 0.9066
# Epoch 13/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6137 - loss: 0.9813
# Epoch 14/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6046 - loss: 0.9679
# Epoch 15/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5915 - loss: 1.0820
# Epoch 16/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6336 - loss: 0.9260
# Epoch 17/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6302 - loss: 0.8675
# Epoch 18/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6258 - loss: 1.0877
# Epoch 19/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6319 - loss: 0.9204
# Epoch 20/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5711 - loss: 1.1597
# Epoch 21/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6163 - loss: 1.0430
# Epoch 22/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6037 - loss: 1.0630
# Epoch 23/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6193 - loss: 0.8913
# Epoch 24/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5881 - loss: 0.9161
# Epoch 25/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6343 - loss: 0.9861
# Epoch 26/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6213 - loss: 1.0543
# Epoch 27/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6213 - loss: 0.9322
# Epoch 28/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6469 - loss: 0.8847
# Epoch 29/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5940 - loss: 1.0801
# Epoch 30/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6352 - loss: 0.8832
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 📊 DL Classification Report (Balanced):
#
#               precision    recall  f1-score   support
#
#     negative       1.00      0.33      0.50         6
#      neutral       0.00      0.00      0.00        48
#     positive       0.63      1.00      0.78        83
#
#     accuracy                           0.62       137
#    macro avg       0.54      0.44      0.43       137
# weighted avg       0.43      0.62      0.49       137
#
# ✅ DL sentiment model trained with class balancing
#
# --- TRAINING AUTOENCODER RECOMMENDER ---
# Epoch 1/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.4539
# Epoch 2/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4226
# Epoch 3/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.3849
# Epoch 4/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.3456
# Epoch 5/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.3083
# Epoch 6/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.2537
# Epoch 7/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.2277
# Epoch 8/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1996
# Epoch 9/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1664
# Epoch 10/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1444
# Epoch 11/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1128
# Epoch 12/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0884
# Epoch 13/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0759
# Epoch 14/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0551
# Epoch 15/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0457
# Epoch 16/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0318
# Epoch 17/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0252
# Epoch 18/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0209
# Epoch 19/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0199
# Epoch 20/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0185
# Epoch 21/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0157
# Epoch 22/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0135
# Epoch 23/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0136
# Epoch 24/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0166
# Epoch 25/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0179
# Epoch 26/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0158
# Epoch 27/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0144
# Epoch 28/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0159
# Epoch 29/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0150
# Epoch 30/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0139
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ✅ Autoencoder trained
#
# --- PREPARING RECOMMENDATION DATA ---
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# /tmp/ipython-input-1528632557.py:178: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['text'] = df['product_name'] + " " + df['category']
# ✅ Recommendation data ready
#
# Enter product name (or exit): watch
#
# ✅ Recommendations for 'watch':
#
# Product: 1. ZEBRONICS Zeb-Blitz with DO...
# 4174 Ratings&25 Reviews
# ₹2,29961% off
# Category: Wearables
# Rating: 4.0 | Price: ₹2299.0
# --------------------------------------------------
# Product: 5. beatXP Unbound Nova 1.96” A...
# 4.21,709 Ratings&118 Reviews
# ₹3,29958% off
# Category: Wearables
# Rating: 4.2 | Price: ₹3299.0
# --------------------------------------------------
# Product: 2. boAt Lunar Discovery w/ Tur...
# 432,754 Ratings&1,787 Reviews
# ₹1,49982% off
# Category: Wearables
# Rating: 4.0 | Price: ₹1499.0
# --------------------------------------------------
# Product: 5. Noise Pulse 3 1.96'' Displa...
# 4.177,586 Ratings&4,075 Reviews
# ₹1,09984% off
# Category: Wearables
# Rating: 4.1 | Price: ₹1099.0
# --------------------------------------------------
# Product: 3. boAt Storm call 3 w/TBT Nav...
# 4.14,21,649 Ratings&23,333 Reviews
# ₹1,39983% off
# Category: Wearables
# Rating: 4.1 | Price: ₹1399.0
# --------------------------------------------------
#
# Enter product name (or exit): headphone
#
# ✅ Recommendations for 'headphone':
#
# Product: 2. Zebur HEADPHONE with 2 PAIR...
# 3.26 Ratings&1 Reviews
# ₹54839% off
# Category: Wearables
# Rating: 3.2 | Price: ₹548.0
# --------------------------------------------------
# Product: 3. Unix Wireless Headphones I ...
# 3.97,935 Ratings&499 Reviews
# ₹75069% off
# Category: Wearables
# Rating: 3.9 | Price: ₹750.0
# --------------------------------------------------
# Product: 1. Noise Master Buds Max, Soun...
# 4.479 Ratings&20 Reviews
# ₹11,999
# Category: Wearables
# Rating: 4.4 | Price: ₹11999.0
# --------------------------------------------------
# Product: 5. Sennheiser HD 400S Closed B...
# 4.3136 Ratings&13 Reviews
# ₹3,99020% off
# Category: Wearables
# Rating: 4.3 | Price: ₹3990.0
# --------------------------------------------------
# Product: 4. Sennheiser MOMENTUM 4 Wirel...
# 4.3264 Ratings&27 Reviews
# ₹25,98925% off
# Category: Wearables
# Rating: 4.3 | Price: ₹25989.0
# --------------------------------------------------
#
# Enter product name (or exit): exit

# %%
# ===============================
# WEARABLES – LSTM VERSION
# ===============================

import pandas as pd
import numpy as np
import os
import glob
import joblib

from sklearn.preprocessing import MinMaxScaler, LabelEncoder
from sklearn.metrics import classification_report
from sklearn.metrics.pairwise import cosine_similarity

from sentence_transformers import SentenceTransformer

import tensorflow as tf
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import LSTM, Attention, Reshape, Flatten


# ===============================
# LOAD DATA
# ===============================
def load_datasets_from_folder(folder_path):
    all_files = glob.glob(os.path.join(folder_path, "*.csv"))
    if not all_files:
        raise Exception("No CSV files found!")

    df = pd.concat([pd.read_csv(f) for f in all_files], ignore_index=True)
    print(f"Loaded {len(df)} records")
    return df


# ===============================
# SENTIMENT PREPROCESSING
# ===============================
def fill_and_encode_sentiment(df):

    def rating_to_sentiment(r):
        if pd.isna(r):
            return 'neutral'
        elif r >= 4:
            return 'positive'
        elif r >= 3:
            return 'neutral'
        else:
            return 'negative'

    df['sentiment'] = df['sentiment'].fillna(
        df['overall_rating'].apply(rating_to_sentiment)
    )

    df['sentiment'] = df['sentiment'].str.lower().str.strip()

    sentiment_map = {'negative': 0, 'neutral': 1, 'positive': 2}
    df['sentiment_score'] = df['sentiment'].map(sentiment_map)

    return df


# ===============================
# DL SENTIMENT CLASSIFIER
# ===============================
def train_dl_sentiment_model(df):
    print("\n--- TRAINING DL SENTIMENT CLASSIFIER (BALANCED) ---")

    df = df.dropna(subset=['overall_rating', 'sentiment_score'])

    X = df[['overall_rating']].values
    y = df['sentiment_score'].values

    scaler = MinMaxScaler()
    X = scaler.fit_transform(X)

    y_cat = tf.keras.utils.to_categorical(y, num_classes=3)

    # 🔹 COMPUTE CLASS WEIGHTS
    class_counts = np.bincount(y)
    total = len(y)

    class_weights = {
        i: total / (3 * count) for i, count in enumerate(class_counts)
    }

    print("Class weights:", class_weights)

    # 🔹 DL MODEL
    model = tf.keras.Sequential([
        Dense(32, activation='relu', input_shape=(1,)),
        Dense(16, activation='relu'),
        Dense(3, activation='softmax')
    ])

    model.compile(
        optimizer='adam',
        loss='categorical_crossentropy',
        metrics=['accuracy']
    )

    model.fit(
        X,
        y_cat,
        epochs=30,
        batch_size=32,
        class_weight=class_weights,
        verbose=1
    )

    # 🔹 EVALUATION
    y_pred = model.predict(X)
    y_pred_labels = np.argmax(y_pred, axis=1)

    print("\n📊 DL Classification Report (Balanced):\n")
    print(classification_report(
        y,
        y_pred_labels,
        target_names=['negative', 'neutral', 'positive'],
        zero_division=0
    ))

    model.save("dl_sentiment_model.h5")
    joblib.dump(scaler, "dl_sentiment_scaler.pkl")

    print("✅ DL sentiment model trained with class balancing")


# ===============================
# LSTM + ATTENTION RECOMMENDER (DL)
# ===============================
def train_lstm_attention_recommender(df):
    print("\n--- TRAINING LSTM + ATTENTION RECOMMENDER ---")

    df = df.dropna(subset=['overall_rating', 'sentiment_score', 'product_price'])

    # 🔹 Feature matrix
    X = df[['overall_rating', 'sentiment_score', 'product_price']].values
    X = MinMaxScaler().fit_transform(X)

    # 🔹 Convert to sequence format (timesteps = features)
    # Shape: (samples, timesteps, features_per_step)
    X_seq = X.reshape((X.shape[0], X.shape[1], 1))

    # 🔹 INPUT
    input_layer = Input(shape=(X_seq.shape[1], 1))

    # 🔹 LSTM
    lstm_out = LSTM(64, return_sequences=True)(input_layer)

    # 🔹 ATTENTION
    attention_out = Attention()([lstm_out, lstm_out])

    # 🔹 FLATTEN
    flat = Flatten()(attention_out)

    # 🔹 OUTPUT (reconstruct input features)
    output_layer = Dense(X.shape[1], activation='linear')(flat)

    # 🔹 MODEL
    model = Model(inputs=input_layer, outputs=output_layer)

    model.compile(
        optimizer='adam',
        loss=tf.keras.losses.MeanSquaredError()
    )

    model.fit(
        X_seq,
        X,
        epochs=30,
        batch_size=32,
        verbose=1
    )

    model.save("lstm_attention_recommender.h5")

    print("✅ LSTM + Attention recommender trained")

# ===============================
# PREPARE RECOMMENDATION DATA
# ===============================
def prepare_recommendation_data(df):
    print("\n--- PREPARING RECOMMENDATION DATA ---")

    df = df.dropna(subset=[
        'product_name', 'category',
        'product_price', 'overall_rating', 'sentiment_score'
    ])

    features = df[['overall_rating', 'sentiment_score', 'product_price']]
    scaler = MinMaxScaler()
    features_scaled = scaler.fit_transform(features)

    similarity_matrix = cosine_similarity(features_scaled)

    joblib.dump(df, "products_data.pkl")
    joblib.dump(similarity_matrix, "similarity_matrix.pkl")

    model_embed = SentenceTransformer('all-MiniLM-L6-v2')
    df['text'] = df['product_name'] + " " + df['category']
    embeddings = model_embed.encode(df['text'].tolist(), convert_to_tensor=True)

    joblib.dump(embeddings.cpu().numpy(), "product_embeddings.pkl")
    joblib.dump(model_embed, "embedding_model.pkl")

    print("✅ Recommendation data ready")


# ===============================
# RECOMMEND PRODUCTS
# ===============================
def recommend_products(user_input, top_n=5):

    df = joblib.load("products_data.pkl")
    embeddings = joblib.load("product_embeddings.pkl")
    model_embed = joblib.load("embedding_model.pkl")

    query_emb = model_embed.encode(user_input, convert_to_tensor=True)
    scores = cosine_similarity(query_emb.reshape(1, -1), embeddings)[0]

    top_idx = np.argsort(scores)[::-1][:top_n]

    print(f"\n✅ Recommendations for '{user_input}':\n")

    for i in top_idx:
        p = df.iloc[i]
        print(f"Product: {p['product_name']}")
        print(f"Category: {p['category']}")
        print(f"Rating: {p['overall_rating']} | Price: ₹{p['product_price']}")
        print("-" * 50)


# ===============================
# MAIN
# ===============================
if __name__ == "__main__":

    DATA_FOLDER = r"/content/Wearables"

    df = load_datasets_from_folder(DATA_FOLDER)
    df = fill_and_encode_sentiment(df)

    # Clean price globally
    df['product_price'] = (
        df['product_price']
        .astype(str)
        .str.replace(r'[₹,\s]', '', regex=True)
    )
    df['product_price'] = pd.to_numeric(df['product_price'], errors='coerce')

    train_dl_sentiment_model(df)
    train_lstm_attention_recommender(df)
    prepare_recommendation_data(df)

    while True:
        name = input("\nEnter product name (or exit): ")
        if name.lower() == "exit":
            break
        recommend_products(name)
# Out:
# Loaded 150 records
#
# --- TRAINING DL SENTIMENT CLASSIFIER (BALANCED) ---
# Class weights: {0: np.float64(7.611111111111111), 1: np.float64(0.9513888888888888), 2: np.float64(0.5502008032128514)}
# Epoch 1/30
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6190 - loss: 1.0487
# Epoch 2/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5986 - loss: 1.0841
# Epoch 3/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5995 - loss: 0.9763
# Epoch 4/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6290 - loss: 1.1514
# Epoch 5/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6006 - loss: 1.0579
# Epoch 6/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6106 - loss: 1.0680
# Epoch 7/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6106 - loss: 1.0407
# Epoch 8/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5772 - loss: 1.2149
# Epoch 9/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5833 - loss: 1.1868
# Epoch 10/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6167 - loss: 1.2669
# Epoch 11/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6315 - loss: 1.0918
# Epoch 12/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6332 - loss: 1.0415
# Epoch 13/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6323 - loss: 1.1362
# Epoch 14/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5868 - loss: 1.0262
# Epoch 15/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6232 - loss: 1.0247
# Epoch 16/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6024 - loss: 1.0885
# Epoch 17/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6189 - loss: 0.9923
# Epoch 18/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5907 - loss: 1.0857
# Epoch 19/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6171 - loss: 0.9659
# Epoch 20/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6493 - loss: 1.0875
# Epoch 21/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5846 - loss: 1.0341
# Epoch 22/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6002 - loss: 1.0557
# Epoch 23/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6427 - loss: 1.1105
# Epoch 24/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6154 - loss: 1.0430
# Epoch 25/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6111 - loss: 0.9665
# Epoch 26/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5538 - loss: 0.9918
# Epoch 27/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5976 - loss: 1.1846
# Epoch 28/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6154 - loss: 0.9988
# Epoch 29/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6215 - loss: 1.0386
# Epoch 30/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5937 - loss: 0.9139
# WARNING:tensorflow:5 out of the last 15 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7f78c6f3e480> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/5 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# WARNING:tensorflow:5 out of the last 11 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7f78c6f3e480> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
#
# 📊 DL Classification Report (Balanced):
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
#               precision    recall  f1-score   support
#
#     negative       1.00      0.17      0.29         6
#      neutral       0.00      0.00      0.00        48
#     positive       0.61      1.00      0.76        83
#
#     accuracy                           0.61       137
#    macro avg       0.54      0.39      0.35       137
# weighted avg       0.42      0.61      0.47       137
#
# ✅ DL sentiment model trained with class balancing
#
# --- TRAINING LSTM + ATTENTION RECOMMENDER ---
# Epoch 1/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.4455
# Epoch 2/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.3648
# Epoch 3/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.3106
# Epoch 4/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2522
# Epoch 5/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1914
# Epoch 6/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1367
# Epoch 7/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0765
# Epoch 8/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0388
# Epoch 9/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0167
# Epoch 10/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0174
# Epoch 11/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0202
# Epoch 12/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0145
# Epoch 13/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0125
# Epoch 14/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0115
# Epoch 15/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0153
# Epoch 16/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0155
# Epoch 17/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0126
# Epoch 18/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0129
# Epoch 19/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0134
# Epoch 20/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0125
# Epoch 21/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0113
# Epoch 22/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0136
# Epoch 23/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0112
# Epoch 24/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0116
# Epoch 25/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0097
# Epoch 26/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0107
# Epoch 27/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0115
# Epoch 28/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0120
# Epoch 29/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0119
# Epoch 30/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0109
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ✅ LSTM + Attention recommender trained
#
# --- PREPARING RECOMMENDATION DATA ---
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# /tmp/ipython-input-2143570461.py:202: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['text'] = df['product_name'] + " " + df['category']
# ✅ Recommendation data ready
#
# Enter product name (or exit): exit

# %%
# ===============================
# WEARABLES - CNN VERSION
# ===============================

import pandas as pd
import numpy as np
import os
import glob
import joblib

from sklearn.preprocessing import MinMaxScaler, LabelEncoder
from sklearn.metrics import classification_report
from sklearn.metrics.pairwise import cosine_similarity

from sentence_transformers import SentenceTransformer

import tensorflow as tf
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Conv1D, GlobalAveragePooling1D
from tensorflow.keras.layers import Attention, Reshape


# ===============================
# LOAD DATA
# ===============================
def load_datasets_from_folder(folder_path):
    all_files = glob.glob(os.path.join(folder_path, "*.csv"))
    if not all_files:
        raise Exception("No CSV files found!")

    df = pd.concat([pd.read_csv(f) for f in all_files], ignore_index=True)
    print(f"Loaded {len(df)} records")
    return df


# ===============================
# SENTIMENT PREPROCESSING
# ===============================
def fill_and_encode_sentiment(df):

    def rating_to_sentiment(r):
        if pd.isna(r):
            return 'neutral'
        elif r >= 4:
            return 'positive'
        elif r >= 3:
            return 'neutral'
        else:
            return 'negative'

    df['sentiment'] = df['sentiment'].fillna(
        df['overall_rating'].apply(rating_to_sentiment)
    )

    df['sentiment'] = df['sentiment'].str.lower().str.strip()

    sentiment_map = {'negative': 0, 'neutral': 1, 'positive': 2}
    df['sentiment_score'] = df['sentiment'].map(sentiment_map)

    return df


# ===============================
# DL SENTIMENT CLASSIFIER
# ===============================
def train_dl_sentiment_model(df):
    print("\n--- TRAINING DL SENTIMENT CLASSIFIER (BALANCED) ---")

    df = df.dropna(subset=['overall_rating', 'sentiment_score'])

    df['neutral_distance'] = np.abs(df['overall_rating'] - 3)

    X = df[['overall_rating', 'neutral_distance']].values

    y = df['sentiment_score'].values

    scaler = MinMaxScaler()
    X = scaler.fit_transform(X)

    y_cat = tf.keras.utils.to_categorical(y, num_classes=3)

    # 🔹 COMPUTE CLASS WEIGHTS
    class_counts = np.bincount(y)
    total = len(y)

    class_weights = {
        i: total / (3 * count) for i, count in enumerate(class_counts)
    }

    print("Class weights:", class_weights)

    # 🔹 DL MODEL
    model = tf.keras.Sequential([
        Dense(32, activation='relu', input_shape=(2,)),
        Dense(16, activation='relu'),
        Dense(3, activation='softmax')
    ])

    model.compile(
        optimizer='adam',
        loss=tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.1),
        metrics=['accuracy']
    )

    model.fit(
        X,
        y_cat,
        epochs=30,
        batch_size=32,
        class_weight=class_weights,
        verbose=1
    )

    # 🔹 EVALUATION
    y_pred = model.predict(X)
    y_pred_labels = np.argmax(y_pred, axis=1)

    print("\n📊 DL Classification Report (Balanced):\n")
    print(classification_report(
        y,
        y_pred_labels,
        target_names=['negative', 'neutral', 'positive'],
        zero_division=0
    ))

    model.save("dl_sentiment_model.h5")
    joblib.dump(scaler, "dl_sentiment_scaler.pkl")

    print("✅ DL sentiment model trained with class balancing")


# ===============================
# CNN + ATTENTION RECOMMENDER (DL)
# ===============================
def train_cnn_attention_recommender(df):
    print("\n--- TRAINING CNN + ATTENTION RECOMMENDER ---")

    df = df.dropna(subset=['overall_rating', 'sentiment_score', 'product_price'])

    # 🔹 Feature matrix
    df['neutral_distance'] = np.abs(df['overall_rating'] - 3)

    X = df[['overall_rating', 'neutral_distance']].values

    X = MinMaxScaler().fit_transform(X)

    # 🔹 Reshape for CNN
    # Shape: (samples, timesteps, channels)
    X_seq = X.reshape((X.shape[0], X.shape[1], 1))

    # 🔹 INPUT
    input_layer = Input(shape=(X_seq.shape[1], 1))

    # 🔹 CNN layers
    conv1 = Conv1D(filters=64, kernel_size=2, activation='relu', padding='same')(input_layer)
    conv2 = Conv1D(filters=32, kernel_size=2, activation='relu', padding='same')(conv1)

    # 🔹 ATTENTION
    attention_out = Attention()([conv2, conv2])

    # 🔹 POOLING
    pooled = GlobalAveragePooling1D()(attention_out)

    # 🔹 OUTPUT (reconstruction)
    output_layer = Dense(X.shape[1], activation='linear')(pooled)

    # 🔹 MODEL
    model = Model(inputs=input_layer, outputs=output_layer)

    model.compile(
        optimizer='adam',
        loss=tf.keras.losses.MeanSquaredError()
    )

    model.fit(
        X_seq,
        X,
        epochs=30,
        batch_size=32,
        verbose=1
    )

    model.save("cnn_attention_recommender.h5")

    print("✅ CNN + Attention recommender trained")

# ===============================
# PREPARE RECOMMENDATION DATA
# ===============================
def prepare_recommendation_data(df):
    print("\n--- PREPARING RECOMMENDATION DATA ---")

    df = df.dropna(subset=[
        'product_name', 'category',
        'product_price', 'overall_rating', 'sentiment_score'
    ])

    features = df[['overall_rating', 'sentiment_score', 'product_price']]
    scaler = MinMaxScaler()
    features_scaled = scaler.fit_transform(features)

    similarity_matrix = cosine_similarity(features_scaled)

    joblib.dump(df, "products_data.pkl")
    joblib.dump(similarity_matrix, "similarity_matrix.pkl")

    model_embed = SentenceTransformer('all-MiniLM-L6-v2')
    df['text'] = df['product_name'] + " " + df['category']
    embeddings = model_embed.encode(df['text'].tolist(), convert_to_tensor=True)

    joblib.dump(embeddings.cpu().numpy(), "product_embeddings.pkl")
    joblib.dump(model_embed, "embedding_model.pkl")

    print("✅ Recommendation data ready")


# ===============================
# RECOMMEND PRODUCTS
# ===============================
def recommend_products(user_input, top_n=5):

    df = joblib.load("products_data.pkl")
    embeddings = joblib.load("product_embeddings.pkl")
    model_embed = joblib.load("embedding_model.pkl")

    # 🔹 Load CNN model
    cnn_model = tf.keras.models.load_model("cnn_attention_recommender.h5")

    # 🔹 Prepare features
    df['neutral_distance'] = np.abs(df['overall_rating'] - 3)
    X = df[['overall_rating', 'neutral_distance']].values
    X = MinMaxScaler().fit_transform(X)
    X_seq = X.reshape((X.shape[0], X.shape[1], 1))

    # 🔹 CNN reconstruction error
    recon = cnn_model.predict(X_seq, verbose=0)
    recon_error = np.mean(np.square(X - recon), axis=1)
    df['dl_score'] = -recon_error

    # 🔹 Semantic similarity
    query_emb = model_embed.encode(user_input, convert_to_tensor=True)
    semantic_scores = cosine_similarity(
        query_emb.reshape(1, -1), embeddings
    )[0]

    # 🔹 Final hybrid score
    df['final_score'] = 0.7 * semantic_scores + 0.3 * df['dl_score'].values

    top_idx = df['final_score'].nlargest(top_n).index

    print(f"\n✅ Recommendations for '{user_input}':\n")

    for i in top_idx:
        p = df.loc[i]
        print(f"Product: {p['product_name']}")
        print(f"Category: {p['category']}")
        print(f"Rating: {p['overall_rating']} | Price: ₹{p['product_price']}")
        print("-" * 50)


# ===============================
# MAIN
# ===============================
if __name__ == "__main__":

    DATA_FOLDER = r"/content/Wearables"

    df = load_datasets_from_folder(DATA_FOLDER)
    df = fill_and_encode_sentiment(df)

    # Clean price globally
    df['product_price'] = (
        df['product_price']
        .astype(str)
        .str.replace(r'[₹,\s]', '', regex=True)
    )
    df['product_price'] = pd.to_numeric(df['product_price'], errors='coerce')

    train_dl_sentiment_model(df)
    train_cnn_attention_recommender(df)
    prepare_recommendation_data(df)

    while True:
        name = input("\nEnter product name (or exit): ")
        if name.lower() == "exit":
            break
        recommend_products(name)
# Out:
# Loaded 150 records
#
# --- TRAINING DL SENTIMENT CLASSIFIER (BALANCED) ---
# Class weights: {0: np.float64(7.611111111111111), 1: np.float64(0.9513888888888888), 2: np.float64(0.5502008032128514)}
# Epoch 1/30
# /tmp/ipython-input-2170219327.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['neutral_distance'] = np.abs(df['overall_rating'] - 3)
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.1783 - loss: 1.0273
# Epoch 2/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6264 - loss: 1.0745
# Epoch 3/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6328 - loss: 1.0960
# Epoch 4/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6373 - loss: 1.0476
# Epoch 5/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6430 - loss: 1.0489
# Epoch 6/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6465 - loss: 1.1101
# Epoch 7/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6503 - loss: 1.0522
# Epoch 8/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6616 - loss: 1.0757
# Epoch 9/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6665 - loss: 1.0413
# Epoch 10/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6730 - loss: 1.0039
# Epoch 11/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6187 - loss: 1.1501
# Epoch 12/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6738 - loss: 1.1506
# Epoch 13/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6586 - loss: 0.9884
# Epoch 14/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6543 - loss: 1.1692
# Epoch 15/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6513 - loss: 0.9709
# Epoch 16/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6699 - loss: 1.0716
# Epoch 17/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6304 - loss: 0.9705
# Epoch 18/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6591 - loss: 0.9624
# Epoch 19/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6543 - loss: 1.0062
# Epoch 20/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6921 - loss: 1.0582
# Epoch 21/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6682 - loss: 1.0029
# Epoch 22/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6521 - loss: 0.9574
# Epoch 23/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6500 - loss: 0.9666
# Epoch 24/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7557 - loss: 1.0165
# Epoch 25/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7141 - loss: 0.9800
# Epoch 26/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7375 - loss: 0.9727
# Epoch 27/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7430 - loss: 1.0591
# Epoch 28/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.7651 - loss: 1.0354
# Epoch 29/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7412 - loss: 0.9143
# Epoch 30/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7204 - loss: 0.8917
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
#
# 📊 DL Classification Report (Balanced):
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
#               precision    recall  f1-score   support
#
#     negative       1.00      0.17      0.29         6
#      neutral       0.82      0.38      0.51        48
#     positive       0.73      1.00      0.84        83
#
#     accuracy                           0.74       137
#    macro avg       0.85      0.51      0.55       137
# weighted avg       0.77      0.74      0.70       137
#
# ✅ DL sentiment model trained with class balancing
#
# --- TRAINING CNN + ATTENTION RECOMMENDER ---
# Epoch 1/30
# /tmp/ipython-input-2170219327.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['neutral_distance'] = np.abs(df['overall_rating'] - 3)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.3711
# Epoch 2/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2636
# Epoch 3/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1804
# Epoch 4/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1105
# Epoch 5/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0502
# Epoch 6/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0127
# Epoch 7/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0050
# Epoch 8/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0101
# Epoch 9/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0103
# Epoch 10/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0040
# Epoch 11/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0025
# Epoch 12/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0041
# Epoch 13/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0029
# Epoch 14/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0022
# Epoch 15/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0026
# Epoch 16/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0016
# Epoch 17/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0027
# Epoch 18/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0019
# Epoch 19/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0021
# Epoch 20/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0015
# Epoch 21/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0011
# Epoch 22/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0012
# Epoch 23/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 8.3530e-04
# Epoch 24/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0015
# Epoch 25/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.9509e-04
# Epoch 26/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.6788e-04
# Epoch 27/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0012
# Epoch 28/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.9515e-04
# Epoch 29/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.1454e-04
# Epoch 30/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 4.9005e-04
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ✅ CNN + Attention recommender trained
#
# --- PREPARING RECOMMENDATION DATA ---
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# /tmp/ipython-input-2170219327.py:210: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['text'] = df['product_name'] + " " + df['category']
# ✅ Recommendation data ready
#
# Enter product name (or exit): exit
